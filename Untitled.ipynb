# %%
import os
import shutil
from Settings import processingFolder, localfolder
import json
import pandas as pd
from tqdm import tqdm


def copyfilefromsource():
    src_files = os.listdir(localfolder)
    for file_name in src_files:
        full_file_name = os.path.join(localfolder, file_name)
        if os.path.isfile(full_file_name):
            shutil.copy(full_file_name, processingFolder)

""" def changeDateFormat():
    archivos = listOfFiles()
    for archivo in archivos[0:1]:
        with open(processingFolder+archivo) as json_file:
            data = json.load(json_file) """

class iterAutores:
    def __init__(self):
        self.archivos = os.listdir(processingFolder)
        self.index = 0
        
    def __iter__(self):
        return self
    
    def __next__(self):
        try:
            archivo = self.archivos[self.index]
            if archivo == "scrappingLog.json":
                raise StopIteration() 
            with open(processingFolder+archivo) as json_file:
                data = json.load(json_file)
        except IndexError:
            raise StopIteration()
        self.index += 1
        return data

def listadoUnicoDeNotas():
    listado = []
    for autor in tqdm(iterAutores()):
        if not "notas" in autor:
            print (autor)
        notas = autor["notas"]
        for idnota, nota in notas.items():
            nota["idnota"] = idnota
            listado.append(nota)
    return listado

def listadoUnicoDeAutores():
    listado = []
    for autor in tqdm(iterAutores()):
        autor["NotasEncontradas"] = len(autor["notas"])
        del autor["notas"]
        listado.append(autor)
    return listado

# %%
#copyfilefromsource()
autores = pd.DataFrame(listadoUnicoDeAutores())
notas = pd.DataFrame(listadoUnicoDeNotas())
# Out:
# 8831it [01:51, 79.46it/s]
# 8831it [00:08, 999.34it/s]

# %%
autores.to_pickle("./store/infoAutores.pkl")
notas.to_pickle("./store/in")

# %%
autores.head()
# Out:
#                                                  Bio  FinalizadoCorrectamente  \
# 0  \n                            Periodista desde...                     True
# 1                                               None                     True
# 2                                               None                     True
# 3                                               None                     True
# 4                                               None                     True
#
#     FotoId                                            FotoUrl    Id  \
# 0  2089285  https://bucket2.glanacion.com/anexos/fotos/85/...     1
# 1     None                                               None    10
# 2  2279647  https://bucket3.glanacion.com/anexos/fotos/47/...   100
# 3     None                                               None  1000
# 4     None                                               None  1001
#
#                                                Medio             Nombre  \
# 0  \n                        LA NACION\n         ...   Mariano Grondona
# 1  \n                        LA NACION\n         ...      Jorge Rosales
# 2  \n                        LA NACION\n         ...  Claudio Jacquelin
# 3  \n                        MEDIO: El País \n   ...      Marcela Dobal
# 4  \n                        MEDIO: El País\n    ...   Fabián Tiscornia
#
#    NotasEncontradas                                        Url  \
# 0              1162     https://www.lanacion.com.ar/autor/id-1
# 1              1733    https://www.lanacion.com.ar/autor/id-10
# 2               537   https://www.lanacion.com.ar/autor/id-100
# 3                 1  https://www.lanacion.com.ar/autor/id-1000
# 4                 2  https://www.lanacion.com.ar/autor/id-1001
#
#                       lastRun  \
# 0  2019-11-03T19:21:48.899631
# 1  2019-11-03T19:22:13.614823
# 2  2019-11-03T19:25:11.649474
# 3  2019-11-04T07:50:30.429140
# 4  2019-11-04T07:50:31.804513
#
#                                           messagelog  notasVacias
# 0  [starting new records, time: 2019-11-02 21:02:...            0
# 1  [starting new records, time: 2019-11-02 22:00:...            0
# 2  [starting new records, time: 2019-11-03 06:40:...            0
# 3  [starting new records, time: 2019-11-04 07:50:...            0
# 4  [starting new records, time: 2019-11-04 07:50:...            0

# %%
autores.sort_values(by=["NotasEncontradas"],ascending=False).head(30)
notasHugo = notas[notas["IdAutor"]==97]
notasHugo.tail()
# Out:
#                       Fecha      Id  IdAutor  \
# 357488  09 DE ENERO DE 2002  365324       97
# 357489  08 DE ENERO DE 2002  365109       97
# 357490  06 DE ENERO DE 2002  364606       97
# 357491  05 DE ENERO DE 2002  364266       97
# 357492  04 DE ENERO DE 2002  364038       97
#
#                                                    Imagen ImagenId  \
# 357488  https://bucket3.glanacion.com/anexos/fotos/68/...   125068
# 357489  https://bucket2.glanacion.com/anexos/fotos/95/...   124995
# 357490                                               None     None
# 357491  https://bucket2.glanacion.com/anexos/fotos/55/...   124655
# 357492                                               None     None
#
#                                                      Link   Seccion  Tema  \
# 357488  https://www.lanacion.com.ar/politica/extendier...  politica  None
# 357489  https://www.lanacion.com.ar/politica/el-dolar-...  politica  None
# 357490  https://www.lanacion.com.ar/sociedad/preven-un...  sociedad  None
# 357491  https://www.lanacion.com.ar/economia/por-el-co...  economia  None
# 357492  https://www.lanacion.com.ar/politica/prorrogan...  politica  None
#
#        TemaId  idnota
# 357488   None  365324
# 357489   None  365109
# 357490   None  364606
# 357491   None  364266
# 357492   None  364038

# %%
infoAutores = {}
infoAutores["AutoresSinNotas"] = autores[autores["NotasEncontradas"]==0]["Id"].tolist()
# Out:
#     Bio  FinalizadoCorrectamente FotoId FotoUrl    Id Medio Nombre  \
# 11  NaN                     True    NaN     NaN  1008   NaN    NaN
# 12  NaN                     True    NaN     NaN  1009   NaN    NaN
# 19  NaN                     True    NaN     NaN  1015   NaN    NaN
# 33  NaN                     True    NaN     NaN  1028   NaN    NaN
# 37  NaN                     True    NaN     NaN  1031   NaN    NaN
#
#     NotasEncontradas  Url                     lastRun  \
# 11                 0  NaN  2019-11-04T07:50:52.340802
# 12                 0  NaN  2019-11-04T07:50:53.278271
# 19                 0  NaN  2019-11-04T07:51:27.491821
# 33                 0  NaN  2019-11-04T07:53:21.642097
# 37                 0  NaN  2019-11-04T07:53:35.411058
#
#                                            messagelog  notasVacias
# 11  [starting new records, time: 2019-11-04 07:50:...            0
# 12  [starting new records, time: 2019-11-04 07:50:...            0
# 19  [starting new records, time: 2019-11-04 07:51:...            0
# 33  [starting new records, time: 2019-11-04 07:53:...            0
# 37  [starting new records, time: 2019-11-04 07:53:...            0

# %%
infoAutores
# Out:
# {'AutoresSinNotas': [1008,
#   1009,
#   1015,
#   1028,
#   1031,
#   1035,
#   1037,
#   1058,
#   1074,
#   1081,
#   1083,
#   1089,
#   1090,
#   1095,
#   1099,
#   110,
#   1103,
#   1111,
#   1131,
#   1140,
#   1142,
#   1154,
#   1160,
#   1173,
#   1176,
#   1182,
#   1183,
#   1184,
#   1187,
#   1229,
#   1232,
#   1240,
#   1248,
#   125,
#   1251,
#   126,
#   1265,
#   1287,
#   1294,
#   13,
#   1317,
#   1327,
#   1333,
#   1338,
#   1341,
#   1346,
#   1348,
#   1356,
#   316,
#   317,
#   3173,
#   3176,
#   3191,
#   3192,
#   3201,
#   3209,
#   3223,
#   3224,
#   3232,
#   3237,
#   3249,
#   3253,
#   3266,
#   3269,
#   3282,
#   3288,
#   3289,
#   3294,
#   3324,
#   3334,
#   3336,
#   3337,
#   3365,
#   3378,
#   3379,
#   3385,
#   3386,
#   3387,
#   3407,
#   3420,
#   3421,
#   3422,
#   3435,
#   3447,
#   3448,
#   3449,
#   3454,
#   3473,
#   3492,
#   3511,
#   3516,
#   3517,
#   3531,
#   3538,
#   3542,
#   3543,
#   3547,
#   3561,
#   3563,
#   3569,
#   3572,
#   3576,
#   3577,
#   3591,
#   362,
#   3627,
#   3648,
#   3651,
#   3652,
#   367,
#   3676,
#   3677,
#   3693,
#   3699,
#   3700,
#   3706,
#   3710,
#   3711,
#   3712,
#   3723,
#   3724,
#   3732,
#   3733,
#   3734,
#   3738,
#   3742,
#   3743,
#   3744,
#   3747,
#   3748,
#   3756,
#   3758,
#   376,
#   3760,
#   3761,
#   3762,
#   3763,
#   3765,
#   3766,
#   3767,
#   3768,
#   3769,
#   3775,
#   3776,
#   3777,
#   3778,
#   3793,
#   3794,
#   3795,
#   3796,
#   3797,
#   3798,
#   3802,
#   3803,
#   3804,
#   3805,
#   381,
#   3813,
#   3815,
#   3816,
#   3817,
#   3819,
#   3821,
#   3822,
#   3823,
#   3824,
#   3832,
#   3835,
#   3836,
#   3837,
#   3840,
#   3843,
#   3844,
#   3845,
#   3846,
#   3848,
#   3852,
#   3853,
#   3859,
#   3860,
#   3861,
#   3872,
#   3874,
#   3885,
#   3889,
#   390,
#   3903,
#   391,
#   3918,
#   3919,
#   3920,
#   3922,
#   3924,
#   3925,
#   3926,
#   3927,
#   3928,
#   3929,
#   3930,
#   3931,
#   3932,
#   3933,
#   3934,
#   3936,
#   3945,
#   3966,
#   3982,
#   3986,
#   399,
#   4004,
#   4005,
#   401,
#   4012,
#   4037,
#   4040,
#   4043,
#   4045,
#   4085,
#   4088,
#   4097,
#   4138,
#   4148,
#   4187,
#   4206,
#   4208,
#   4214,
#   4218,
#   4219,
#   4223,
#   4230,
#   4248,
#   4261,
#   428,
#   429,
#   430,
#   4308,
#   4312,
#   4322,
#   4326,
#   4330,
#   437,
#   4387,
#   4396,
#   4416,
#   4433,
#   4434,
#   4451,
#   4456,
#   4474,
#   4479,
#   4488,
#   4494,
#   4500,
#   4501,
#   4502,
#   4510,
#   4519,
#   4557,
#   4574,
#   4575,
#   4584,
#   459,
#   4596,
#   4597,
#   4647,
#   4653,
#   4654,
#   466,
#   467,
#   4719,
#   4732,
#   4733,
#   4743,
#   476,
#   4766,
#   477,
#   4785,
#   4788,
#   479,
#   4797,
#   4812,
#   4817,
#   4830,
#   486,
#   4864,
#   4882,
#   4889,
#   4890,
#   490,
#   4905,
#   4907,
#   4908,
#   4910,
#   4913,
#   4915,
#   4926,
#   4934,
#   4942,
#   4944,
#   4946,
#   4948,
#   4953,
#   4955,
#   4964,
#   4965,
#   4975,
#   4976,
#   4981,
#   4990,
#   4992,
#   5011,
#   5015,
#   5048,
#   5050,
#   5059,
#   5064,
#   5067,
#   5082,
#   5083,
#   5090,
#   5100,
#   5115,
#   5120,
#   5124,
#   5126,
#   5127,
#   5136,
#   5137,
#   5145,
#   5147,
#   517,
#   518,
#   5186,
#   5197,
#   522,
#   5236,
#   524,
#   5241,
#   525,
#   527,
#   5270,
#   5295,
#   5296,
#   5319,
#   5331,
#   5334,
#   5349,
#   5385,
#   5395,
#   5396,
#   5401,
#   5402,
#   5408,
#   5414,
#   5420,
#   5431,
#   5441,
#   5442,
#   5443,
#   5445,
#   5460,
#   5465,
#   5466,
#   5477,
#   5490,
#   5492,
#   5495,
#   5496,
#   551,
#   5514,
#   552,
#   5523,
#   5525,
#   5537,
#   5545,
#   5560,
#   5566,
#   5567,
#   5568,
#   5591,
#   5592,
#   561,
#   5610,
#   5615,
#   5626,
#   5627,
#   5628,
#   563,
#   5637,
#   5638,
#   5645,
#   5647,
#   5656,
#   5658,
#   5660,
#   567,
#   5679,
#   5692,
#   5701,
#   5704,
#   5710,
#   5712,
#   5719,
#   572,
#   5730,
#   5737,
#   5757,
#   5758,
#   5773,
#   5774,
#   5775,
#   5777,
#   5792,
#   5794,
#   5798,
#   5799,
#   5800,
#   5808,
#   5818,
#   5819,
#   5821,
#   5831,
#   5836,
#   5837,
#   5838,
#   584,
#   5849,
#   585,
#   586,
#   5874,
#   5878,
#   5880,
#   5883,
#   5886,
#   5887,
#   5888,
#   5901,
#   5902,
#   5907,
#   5908,
#   5910,
#   5911,
#   5913,
#   5924,
#   5933,
#   5934,
#   5935,
#   5938,
#   5944,
#   5948,
#   595,
#   5955,
#   5959,
#   5965,
#   5966,
#   5967,
#   5973,
#   5982,
#   5989,
#   5993,
#   6,
#   6021,
#   6022,
#   6023,
#   6024,
#   6029,
#   6033,
#   6034,
#   6037,
#   6038,
#   6045,
#   6046,
#   6063,
#   6068,
#   6073,
#   6075,
#   6076,
#   6084,
#   6085,
#   6091,
#   6092,
#   6093,
#   6097,
#   6100,
#   6107,
#   611,
#   6117,
#   6120,
#   6127,
#   6130,
#   6138,
#   6142,
#   6143,
#   6153,
#   6156,
#   6157,
#   6166,
#   6167,
#   6168,
#   6169,
#   6170,
#   618,
#   6196,
#   62,
#   6200,
#   6204,
#   6206,
#   621,
#   6214,
#   6215,
#   6218,
#   6219,
#   6220,
#   6223,
#   624,
#   633,
#   638,
#   640,
#   644,
#   647,
#   654,
#   655,
#   658,
#   664,
#   665,
#   672,
#   678,
#   708,
#   724,
#   731,
#   747,
#   755,
#   760,
#   761,
#   764,
#   769,
#   775,
#   785,
#   791,
#   80,
#   800,
#   811,
#   813,
#   819,
#   822,
#   824,
#   836,
#   838,
#   841,
#   842,
#   844,
#   845,
#   859,
#   862,
#   875,
#   879,
#   913,
#   914,
#   916,
#   920,
#   922,
#   923,
#   924,
#   925,
#   93,
#   932,
#   936,
#   938,
#   94,
#   953,
#   96,
#   965,
#   966,
#   971,
#   974,
#   978,
#   980,
#   983,
#   993]}

# %%
# Out:
# 822
