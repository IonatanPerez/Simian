# %%
import requests
from bs4 import BeautifulSoup

class Clarin:
    
    myname = "Clarin"
    urlhome = "https://www.clarin.com/"
    
    class Home:
    
        url = "https://www.clarin.com/"
       
    
        def __init__ (self):
            self.page = requests.get(self.url)
            if self.page.status_code != 200:
                print (self.page.status_code)
            else:
                print ("Home de " + Clarin.myname + " descargado con exito.")
            self.bpage = BeautifulSoup(self.page.content, 'html.parser')

        def searchthings(self):
            # TODO. Ver que onda https://www.clarin.com/ultimas-noticias/
            # TODO. Ver que onda https://www.clarin.com/noticias-mas-leidas/
            
            # Buscamos las notas pri
            pass
    
    def searchHome(self):
        
        Home = self.Home()
        print (Home.bpage)

# %%
clarin = Clarin()
clarin.searchHome()
# Out:
# Home de Clarin descargado con exito.
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Clarín - Últimas noticias de Argentina y el mundo en Clarín.com</title>
# <link href="https://images.clarin.com" rel="preconnect"/>
# <link href="https://fonts.gstatic.com" rel="preconnect"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="es" http-equiv="Content-Language"/>
# <meta content="es" name="LANGUAGE"/>
# <meta content="Global" name="DISTRIBUTION"/>
# <meta content="all" name="ROBOTS"/>
# <meta content="Clarin.com" name="AUTHOR"/>
# <meta content="noticias, información, videos, diario, newspaper" name="classification"/>
# <meta content="all" name="Googlebot"/>
# <meta content="Clarin.com | Diario Clarin" name="GENERATOR"/>
# <meta content="Clarin.com | Diario Clarin" name="SUBJECT"/>
# <meta content="Clarin.com. Noticias de la Argentina y el mundo. Información actualizada las 24 horas y en español. Informate ya" name="DESCRIPTION"/>
# <meta content="Clarin.com noticias de la Argentina y el mundo actualizadas las 24 horas" name="ABSTRACT"/>
# <meta content="noticias, política, deportes, economía, internacionales, mundo, espectáculos, Argentina, sociedad, ciudades, policiales, internet, tecnología, infografías, fotos, videos, audios, multimedia, clima, claringrilla, humor, blogs, mapas, archivo, edición impresa" name="KEYWORDS"/>
# <meta content="App" name="msApplication-ID"/>
# <meta content="AGEA.MOBILE.Clarin.com_q59wyq0q7cm24" name="msApplication-PackageFamilyName"/>
# <meta content="CE3C588E6E296E3426712C2530D6922F" name="msvalidate.01"/>
# <meta content="www.clarin.com" property="og:url"/>
# <meta content="Clarin.com" property="og:title"/>
# <meta content="https://www.clarin.com/static/CLAClarin/images/Clarin-sahreing-fbk.jpg" property="og:image"/>
# <meta content="Clarin.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="Noticias de la Argentina y el mundo. Información actualizada las 24 horas y en español. Informate ya" property="og:description"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Clarin.com" name="twitter:title"/>
# <meta content="Noticias de la Argentina y el mundo. Información actualizada las 24 horas y en español. Informate ya" name="twitter:description"/>
# <meta content="https://www.clarin.com/static/CLAClarin/images/Clarin-sahreing-fbk.jpg" name="twitter:image:src"/>
# <meta content="clarin.com" name="twitter:image:alt"/>
# <meta content="@clarincom" name="twitter:creator"/>
# <meta content="@clarincom" name="twitter:site"/>
# <meta content="clarin.com" name="twitter:domain"/>
# <meta content="156057357762712" property="fb:pages"/>
# <meta content="411588568884731" property="fb:pages"/>
# <meta content="349870921749715" property="fb:pages"/>
# <meta content="437491989970687" property="fb:app_id"/>
# <meta content="frontpage" name="cXenseParse:pageclass"/>
# <meta content="width=device-width, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="Clarin.com" name="application-name"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="https://www.clarin.com/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/manifest.json?v1.0" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/ms-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <link as="style" href="https://fonts.googleapis.com/css?family=Roboto:400,500,700" rel="preload" type="text/css">
# <link as="style" href="https://static.clarin.com/static/CLAClarin/css/comprimido-home/comprimido-home.css?hash=64c86e7585305b3c1f070bb03a0c416d" rel="preload" type="text/css">
# <script async="" src="https://www.clarin.com/apw.js?v=2" type="text/javascript"></script>
# <script async="" src="https://www.clarin.com/apw.js?f=mod&amp;v=3" type="text/javascript"></script>
# <script src="https://www.clarin.com/weizenbock/dist/min.js" type="text/javascript"></script>
# <script src="https://st-wzb.clarin.com/weizenbock/amazon/min.js " type="text/javascript"></script>
# <script src="https://static.clarin.com/static/CLAClarin/js/clarin.js?hash=ad1d37afda230a8972fe5fe0cfe27405" type="text/javascript"></script>
# <script type="application/ld+json">{"@context": "http://schema.org","@type": "Organization","url": "https://www.clarin.com/","name": "Clarin","sameAs": ["https://www.facebook.com/clarincom/", "https://twitter.com/clarincom"],"foundingDate": "1945-08-28","logo": "https://www.clarin.com/static/CLAClarin/images/logo_clarin.svg","description": "Clarín es el diario de referencia de la sociedad argentina. Desde 1945, sus páginas reflejan la realidad local e internacional con un registro intransferible. Su redacción cuenta con el mayor equipo de periodistas del país, reconocido por sus estándares de calidad y rigor profesional."}</script>
# </link></link></head><!-- t = 1559452069 -->
# <body>
# <!--[if lt IE 9]>
#     <script src="https://static.clarin.com/static/DESGenerico/js/html5shiv.js"></script>
# <![endif]-->
# <!-- layer tripleImpact -->
# <div apikey="BJ7C9NuU" id="wb_meter"></div>
# <div id="bannerTI">
# <div>
# <div class="ad-slot" data-adtype="flotante3" id="flotante3"></div><!-- 1559452068 S -->
# </div>
# </div>
# <!-- layer dhtml -->
# <div>
# <div class="ad-slot" data-adtype="flotante1" id="flotante1"></div><!-- 1559452068 S -->
# </div>
# <!-- layer dhtml -->
# <div>
# <div class="ad-slot" data-adtype="flotante2" id="flotante2"></div><!-- 1559452068 S -->
# </div>
# <div class="wrapper board-home portada">
# <header>
# <div class="menu-overlay"></div>
# <div class="header-content" itemscope="" itemtype="https://schema.org/WPHeader">
# <nav>
# <div class="nav-content container">
# <ul class="nav navbar-nav">
# <li class="dropdown">
# <a class="dropdown-toggle" data-toggle="dropdown"><span class="icon-menu fa fa-bars"></span><span class="menu-name">SECCIONES</span></a>
# <div class="dropdown-menu dropdown">
# <div class="container-submenu">
# <span class="close">x</span>
# <div class="columna">
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/ultimas-noticias/" target="_self">Últimas Noticias</a>
# <span class="toggle-icon section-httpswwwclarincomultimas-noticias"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/videos/" target="_self">Videos</a>
# <span class="toggle-icon section-httpswwwclarincomvideos"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/fotogalerias" target="_blank">Fotogalerías</a>
# <span class="toggle-icon section-httpswwwclarincomfotogalerias"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="/politica/" target="_self">Política</a>
# <span class="toggle-icon section-politica"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="/economia/" target="_self">Economía</a>
# <span class="toggle-icon section-economia"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# <ul class="subsections-col section-economia">
# <li><a href="/economia/divisas-acciones-bonos/" target="_self">Dólar, divisas, acciones y bonos</a></li>
# </ul>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="/sociedad/" target="_self">Sociedad</a>
# <span class="toggle-icon section-sociedad"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="/mundo/" target="_self">Mundo</a>
# <span class="toggle-icon section-mundo"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/cultura/" target="_self">Cultura</a>
# <span class="toggle-icon section-httpswwwclarincomcultura"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="/opinion/" target="_self">Opinión</a>
# <span class="toggle-icon section-opinion"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# <ul class="subsections-col section-opinion">
# <li><a href="/cartas_al_pais/" target="_self">Cartas al País</a></li>
# </ul>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="/ciudades/" target="_self">Ciudades</a>
# <span class="toggle-icon section-ciudades"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="/policiales/" target="_self">Policiales</a>
# <span class="toggle-icon section-policiales"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# </div>
# <div class="columna">
# <ul class="section-col">
# <li class="section-name"><a href="/deportes/" target="_self">Deportes</a>
# <span class="toggle-icon section-deportes"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# <ul class="subsections-col section-deportes">
# <li><a href="https://www.clarin.com/deportes/futbol/" target="_self">Fútbol</a></li>
# <li><a href="https://www.clarin.com/deportes/futbol-internacional/" target="_self">Fútbol Internacional</a></li>
# <li><a href="https://www.clarin.com/deportes/seleccion-nacional/" target="_self">Selección</a></li>
# <li><a href="https://www.clarin.com/deportes/estadisticas.html" target="_self">Estadísticas</a></li>
# <li><a href="https://www.clarin.com/deportes/ascenso/" target="_self">Ascenso</a></li>
# <li><a href="https://www.clarin.com/deportes/tenis/" target="_self">Tenis</a></li>
# <li><a href="https://www.clarin.com/deportes/rugby/" target="_self">Rugby</a></li>
# <li><a href="https://www.clarin.com/deportes/basquet/liga-nacional/" target="_self">Liga Nac. de Básquet</a></li>
# <li><a href="https://www.clarin.com/tema/nba.html" target="_self">NBA</a></li>
# <li><a href="https://www.clarin.com/deportes/hockey/" target="_self">Hockey</a></li>
# <li><a href="https://www.clarin.com/deportes/agenda-deportiva/" target="_self">Agenda Deportiva</a></li>
# </ul>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="/espectaculos/" target="_self">Espectáculos</a>
# <span class="toggle-icon section-espectaculos"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# <ul class="subsections-col section-espectaculos">
# <li><a href="https://www.clarin.com/espectaculos/fama/" target="_self">Fama</a></li>
# <li><a href="https://www.clarin.com/espectaculos/tv/" target="_self">TV</a></li>
# <li><a href="https://www.clarin.com/espectaculos/cine/" target="_self">Cine</a></li>
# <li><a href="https://www.clarin.com/tema/series-y-peliculas.html" target="_self">Series y Películas</a></li>
# <li><a href="https://www.clarin.com/espectaculos/musica/" target="_self">Música</a></li>
# <li><a href="https://www.clarin.com/espectaculos/teatro/" target="_self">Teatro</a></li>
# <li><a href="https://www.clarin.com/espectaculos/teatro/cartelera.html" target="_self">Cartelera de teatro</a></li>
# <li><a href="https://www.clarin.com/espectaculos/cine/cartelera.html" target="_self">Cartelera de cine</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="columna">
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/humor/" target="_self">Humor e Ilustraciones</a>
# <span class="toggle-icon section-httpswwwclarincomhumor"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/entremujeres/" target="_self">Entremujeres</a>
# <span class="toggle-icon section-httpswwwclarincomentremujeres"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/autos/" target="_self">Autos</a>
# <span class="toggle-icon section-httpswwwclarincomautos"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/tecnologia/" target="_self">Tecnología</a>
# <span class="toggle-icon section-httpswwwclarincomtecnologia"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/viajes/" target="_self">Viajes</a>
# <span class="toggle-icon section-httpswwwclarincomviajes"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/buena-vida/" target="_self">Buena vida</a>
# <span class="toggle-icon section-httpswwwclarincombuena-vida"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/rural/" target="_self">Rural</a>
# <span class="toggle-icon section-httpswwwclarincomrural"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/viva/" target="_self">Revista Viva</a>
# <span class="toggle-icon section-httpswwwclarincomviva"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/arq/" target="_self">Arq</a>
# <span class="toggle-icon section-httpswwwclarincomarq"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/revista-enie/" target="_self">Revista Ñ</a>
# <span class="toggle-icon section-httpswwwclarincomrevista-enie"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/videos-documentales-clarin" target="_self">Clarín Docs</a>
# <span class="toggle-icon section-httpswwwclarincomvideos-documentales-clarin"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/br/" target="_self">Clarín em portugués</a>
# <span class="toggle-icon section-httpswwwclarincombr"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# </div>
# <div class="columna">
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/new-york-times-international-weekly" target="_self">NYT International Weekly</a>
# <span class="toggle-icon section-httpswwwclarincomnew-york-times-international-weekly"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/newsletters/" target="_self">Newsletters</a>
# <span class="toggle-icon section-httpswwwclarincomnewsletters"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="http://www.grandt.clarin.com/" target="_blank">Gran DT</a>
# <span class="toggle-icon section-httpwwwgrandtclarincom"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/radio-mitre-vivo/" target="_blank">Radio Mitre en Vivo</a>
# <span class="toggle-icon section-httpswwwclarincomradio-mitre-vivo"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="#" target="_self">Servicios</a>
# <span class="toggle-icon section-home"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# <ul class="subsections-col section-home">
# <li><a href="https://www.clarin.com/claringrilla/" target="_self">Claringrilla</a></li>
# <li><a href="https://www.clarin.com/sudoku/" target="_self">Sudoku</a></li>
# <li><a href="https://www.clarin.com/clima/" target="_self">Clima</a></li>
# <li><a href="https://www.clarin.com/horoscopo.html" target="_self">Horóscopo</a></li>
# <li><a href="https://www.clarin.com/loterias-y-quinielas/" target="_self">Loterías y Quinielas</a></li>
# <li><a href="https://www.clarin.com/feriados/" target="_self">Feriados 2019</a></li>
# <li><a href="https://www.clarin.com/television-argentina/" target="_self">Programación de TV Argentina</a></li>
# <li><a href="http://tapas.clarin.com/" target="_blank">Tapas de Clarín</a></li>
# <li><a href="http://kiosco.clarin.com/" target="_blank">Edición impresa</a></li>
# <li><a href="https://www.clarin.com/ediciones-anteriores/" target="_self">Ediciones anteriores</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="columna">
# <ul class="section-col">
# <li class="section-name"><a href="https://clasificados.clarin.com/" target="_blank">Clasificados</a>
# <span class="toggle-icon section-httpsclasificadosclarincom"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# <ul class="subsections-col section-httpsclasificadosclarincom">
# <li><a href="http://www.deautos.com.ar/" target="_blank">DeAutos</a></li>
# <li><a href="http://www.argenprop.com/" target="_blank">Argenprop</a></li>
# <li><a href="http://www.empleos.clarin.com/postulantes/" target="_blank">Empleos</a></li>
# </ul>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/suscripciones/landing.html" target="_blank">Suscribite</a>
# <span class="toggle-icon section-httpswwwclarincomsuscripcioneslandinghtml"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/noticias-mas-leidas/" target="_self">Las más leídas</a>
# <span class="toggle-icon section-httpswwwclarincomnoticias-mas-leidas"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/temas/" target="_self">Temas</a>
# <span class="toggle-icon section-httpswwwclarincomtemas"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="https://www.clarin.com/tema/especial-clarin.html" target="_blank">Especiales</a>
# <span class="toggle-icon section-httpswwwclarincomtemaespecial-clarinhtml"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# </li>
# </ul>
# <ul class="section-col">
# <li class="section-name"><a href="/contactenos.html" target="_blank">Contactanos</a>
# <span class="toggle-icon section-contactenoshtml"><i aria-hidden="true" class="fa fa-angle-down fa-2"></i><i aria-hidden="true" class="fa fa-angle-up fa-2"></i></span>
# <ul class="subsections-col section-contactenoshtml">
# <li><a href="https://www.clarin.com/preguntas-frecuentes" target="_blank">Ayuda</a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li class="logo-mobile">
# <a href="http://www.clarin.com/">
# <img alt="Clarín" src="https://images.clarin.com/collections/static/logo_clarin.svg"/>
# </a>
# </li>
# <li class="search">
# <i aria-hidden="true" class="fa fa-search fa-2"></i>
# <div class="box-search">
# <form id="buscarForm">
# <input id="search_text" placeholder="Buscar..." type="text" value=""/>
# <input class="btn btnSearch" type="submit" value="BUSCAR"/>
# </form>
# </div>
# </li>
# <li class="isologo">
# <img alt="Clarín" onclick="window.scrollTo(0,0);" src="https://images.clarin.com/collections/static/logo_clarin.svg"/>
# </li>
# <li class="nav-item">
# <a class="link-nav" href="https://www.clarin.com/ultimas-noticias/" target="_self">Últimas Noticias</a>
# </li>
# <li class="nav-item">
# <a class="link-nav" href="https://www.clarin.com/politica/" target="_self">Política</a>
# </li>
# <li class="nav-item">
# <a class="link-nav" href="https://www.clarin.com/mundo/" target="_self">Mundo</a>
# </li>
# <li class="nav-item">
# <a class="link-nav" href="https://www.clarin.com/sociedad/" target="_self">Sociedad</a>
# </li>
# <li class="nav-item">
# <a class="link-nav" href="https://www.clarin.com/policiales/" target="_self">Policiales</a>
# </li>
# <li class="nav-item">
# <a class="link-nav" href="https://www.clarin.com/deportes/" target="_self">Deportes</a>
# </li>
# <li class="nav-item">
# <a class="link-nav" href="https://www.clarin.com/espectaculos/" target="_self">Espectáculos</a>
# </li>
# <li class="nav-item">
# <a class="link-nav clasificados" href="https://clasificados.clarin.com/inicio/index#!/" target="_blank">Clasificados</a>
# </li>
# </ul>
# <ul class="nav-right">
# <li class="suscripcion365"><a href="http://365.clarin.com" target="_blank"></a></li>
# <li class="nav-pase pase-module pase-sticky" id="weisen-sticky" style="display:none;"></li>
# </ul>
# </div>
# </nav>
# <div class="header-services">
# <div class="container">
# <div class="box-slider">
# <div class="swiper-button-prev"><i aria-hidden="true" class="fa fa-angle-left fa-2"></i></div>
# <div class="swiper-container" id="header-services-slider">
# <div class="swiper-wrapper">
# <div class="swiper-slide">
# <a class="" href="https://www.clarin.com/newsletters/" target="_self"><i class="fa fa-envelope-o"></i><span>Newsletters</span></a>
# </div>
# <div class="swiper-slide">
# <a class="" href="https://www.clarin.com/claringrilla" target="_self"><i class="fa fa-table"></i><span>Claringrilla</span></a>
# </div>
# <div class="swiper-slide">
# <a class="" href="https://www.clarin.com/deportes/estadisticas/futbol/primera_a.html" target="_blank"><i class="fa fa-futbol-o"></i><span>Estadísticas</span></a>
# </div>
# <div class="swiper-slide">
# <a class="" href="https://www.clarin.com/economia/divisas-acciones-bonos/" target="_self"><i class="fa fa-usd"></i><span>Dólar</span></a>
# </div>
# <div class="swiper-slide">
# <a class="mitre" href="https://www.clarin.com/radio-mitre-vivo/" target="_blank"><i class="fa fa-headphones"></i><span>Radio Mitre </span></a>
# </div>
# <div class="swiper-slide">
# <a class="" href="https://www.clarin.com/noticias-mas-leidas/" target="_self"><i class="fa fa-file-o"></i><span>Las más leídas</span></a>
# </div>
# <div class="swiper-slide">
# <a class="tapas" href="https://tapas.clarin.com/" target="_blank"><i class="fa fa-newspaper-o"></i><span>Tapa</span></a>
# </div>
# <div class="swiper-slide">
# <a class="" href="https://www.clarin.com/humor/" target="_self"><i class="fa fa-image"></i><span>Humor</span></a>
# </div>
# <div class="swiper-slide">
# <a class="transito" href="https://www.clarin.com/transito.html" target="_self"><i class="fa fa-car"></i><span>Tránsito</span></a>
# </div>
# <div class="swiper-slide">
# <a class="" href="https://www.clarin.com/television-argentina/" target="_self"><i class="fa fa-tv"></i><span>Grilla de TV</span></a>
# </div>
# <div class="swiper-slide">
# <a class="sudoku" href="https://www.clarin.com/sudoku" target="_self"><i class="fa fa-th-large"></i><span>Sudoku</span></a>
# </div>
# <div class="swiper-slide">
# <a class="horoscopo" href="https://www.clarin.com/horoscopo.html" target="_self"><i class="fa fa-moon-o"></i><span>Horóscopo</span></a>
# </div>
# <div class="swiper-slide">
# <a class="feriados" href="https://www.clarin.com/feriados" target="_self"><i class="fa fa-calendar"></i><span>Feriados</span></a>
# </div>
# <div class="swiper-slide">
# <a class="facebook" href="https://www.facebook.com/clarincom" target="_blank"><i class="fa fa-facebook"></i><span>Facebook</span></a>
# </div>
# <div class="swiper-slide">
# <a class="twitter" href="https://twitter.com/clarincom" target="_blank"><i class="fa fa-twitter"></i><span>Twitter</span></a>
# </div>
# <div class="swiper-slide">
# <a class="" href="https://colecciones.clarin.com/" target="_blank"><i class="fa fa-table"></i><span>Colecciones</span></a>
# </div>
# <div class="swiper-slide">
# <a class="" href="https://tienda.mercadolibre.com.ar/clarin" target="_blank"><i class="fa fa-shopping-cart"></i><span>Tienda Clarin</span></a>
# </div>
# </div>
# </div>
# <div class="swiper-button-next"><i aria-hidden="true" class="fa fa-angle-right fa-2"></i></div>
# </div>
# </div>
# <script type="text/javascript">
#         function formatNumber(val){
#             return ('0'+val).slice(-2);
#         }
#
#         function noHayDiario(hoy) {
#             var diasSinDiario = ["01-01","01-05","07-11","25-12"];
#             var hoyFormatted = formatNumber(hoy.getDate())+'-'+formatNumber(hoy.getMonth()+1);
#
#             var founded = false;
#             for(var i=0, len=diasSinDiario.length; i<len && !founded; i++)
#                 if (hoyFormatted == diasSinDiario[i])
#                     founded = true;
#
#             return founded;
#         }
#
#         function createCLANamespace(object) {
#             if(typeof(window.CLA) == 'undefined')
#                 window.CLA = {};
#
#             var objects = [window.CLA, object];
#             window.CLA = objects.reduce(function(r, o){
#                 Object.keys(o).forEach(function (k) {
#                     r[k] = o[k];
#                 });
#                 return r;
#             }, {});
#         }
#
#         function setTapaLink() {
#             var now = new Date();
#             if(now.getHours()<6 || noHayDiario(now)) //no hay diario (obtener el del dia anterior)
#                 now.setDate(now.getDate() - 1);
#
#             var tapa = now.getFullYear()+formatNumber(now.getMonth()+1)+formatNumber(now.getDate());
#             var dia = formatNumber(now.getDate());
#             var mes = formatNumber(now.getMonth()+1);
#             var anio = now.getFullYear();
#             createCLANamespace({tapa:{}});
#             return CLA.tapa.link = 'https://images.clarin.com/tapas/'+anio+'/'+mes+'/'+dia+'/'+tapa+'_thumb.jpg';
#         }
#
#         setTapaLink();
#
#         $(".tapas").click(function(e) {
#
#             e.preventDefault();
#
#             $.magnificPopup.open({
#                 items: {
#                     src: CLA.tapa.link,
#                     type:'image',
#                 },
#                 image: {
#                     verticalFit: false,
#                 },
#                 closeOnContentClick: true,
#                 closeOnBgClick: true,
#                 closeBtnInside: true,
#                 showCloseBtn: true,
#                 modal: false,
#                 callbacks: {
#                     close: function() {
#                     },
#                     open: function() {
#                         $('.mfp-bg').addClass('modal-terminos');
#                     }
#                 },
#             });
#         });
#     </script>
# </div>
# <div class="header-bottom container">
# <div class="logo">
# <figure>
# <a href="http://www.clarin.com/">
# <img alt="Clarín" src="https://images.clarin.com/collections/static/logo_clarin.svg"/>
# </a>
# </figure>
# </div>
# <div class="widgets"><input id="imageHeaderLogoShow" type="hidden" value="1">
# <div class="widget-logo" style="visibility:hidden;"><div id="logoImageHeaderLink"><img src="https://www.clarin.com/bbtfile/3191_20190520eVLujM.gif" style="height:50px;width:150px;cursor:pointer;"/></div></div>
# <div class="widget-clima l">
# <a href="https://www.clarin.com/clima">
# <div class="widget-txt l">
# <span class="city">Buenos Aires</span>
# <span class="temperatura" data-temperatura="13">13.9°<span style="font-size: small;"> ST 14.1°</span></span>
# </div>
# <figure class="widget-img l">
# <img alt="Clima" src="/static/DESClima/images/v3/chicas/0.png"/>
# </figure>
# </a>
# <!-- 0 -->
# </div>
# <!--googleoff: all -->
# <div class="widget l pase-module" id="header-weisen">
# <div id="getGigyaSectionId" style="display: none;">1</div>
# <div class="suscribe" style="display: none;">
# <a href="https://www.clarin.com/suscripciones/landing.html?utm_source=header_suscribite&amp;utm_medium=clarin&amp;utm_campaign=boton&amp;utm_term=boton_header_suscribite&amp;utm_content=organico" target="_blank"><span>Suscribite</span></a>
# </div>
# <div class="paseLog pase_notLoggedIn" style="display: none;">
# <div class="widget-txt widget-ingreso toggle">
# <a class="" id="pase-panel-login" style="display:block; overflow: hidden"><span class="icon-ingreso"></span><span class="login_pase" id="loginLogout"></span></a>
# </div>
# </div>
# <div class="paseLog pase_LoggedIn" style="display: none;">
# <div class="widget-txt widget-ingreso flecha">
# <span class="icon-ingreso"></span>
# <div class="hola">
# <p class="nombre login_pase" id="userFirstName"></p>
# </div>
# </div>
# <div class="opciones subnav" style="display: none;">
# <span class="pic"></span>
# <ul>
# <li><span class="email-usuario"></span></li>
# <li><a class="cuenta-usuario" id="cuenta-usuario">MI CUENTA</a></li>
# <li id="misuscripcion" style="display: none; padding-bottom: 3px;"><a href="http://autogestion.365.com.ar" id="mi_suscripcion">MI SUSCRIPCION</a></li>
# <li class="toggle"><a class="logoff pase_logoff">CERRAR SESIÓN</a></li>
# </ul>
# </div>
# </div>
# <script>
#
#     var status = sasClarinHelper.getKwPw();
#     if (status !=2 ) {
#         $(".suscribe").show();
#         $(document).ready(function() {
#             $(".footer_suscribe").css("display","block");
#         });
#
#     } else if (status == 2) {
#         $(document).ready(function() {
#             $("li#misuscripcion").show();
#         });
#
#     }
# </script>
# </div>
# </input></div>
# </div>
# <div class="hoy-interesa">
# <ul class="container">
# <li>Hoy Interesa</li>
# <li><a href="https://www.clarin.com/tema/ricardo-russo.html" target="_blank">Pediatra detenido</a></li>
# <li><a href="https://www.clarin.com/tema/san-miguel-del-monte.html" target="_blank">Tragedia de Monte</a></li>
# <li><a href="https://www.clarin.com/tema/river-plate.html" target="_blank">River Plate</a></li>
# <li><a href="https://www.clarin.com/tema/elecciones-2019.html" target="_blank">Elecciones 2019</a></li>
# <li class="date"><p>Domingo, 02 de Junio de 2019</p></li>
# </ul>
# </div>
# </div>
# <script type="text/javascript">
#     logoClick = function(e){
#         if(""!=""){
#          var pass_data= {hitType: "event",action: ""};
#          sendGAPageview(pass_data);
#         }
#      };
#
#
#     $(document).ready(function(e) {
#         _auth = WAuth.getUserSync();
#
#         if(_auth != null){
#             _imgshow = $("#imageHeaderLogoShow").val();
#             if(_imgshow == ""){
#                 $(".widget-logo").css("visibility","visible");
#             }else{
#                 if(_auth['subscriptionStatus'] != "subscribed"){
#                     $(".widget-logo").css("visibility","visible");
#                 }
#             }
#         }else{
#             $(".widget-logo").css("visibility","visible");
#         }
#         $("#logoImageHeaderLink").bind('click',function(e){
#              e.stopPropagation();
#              e.preventDefault();
#              logoClick();
#              setTimeout(function(){
#                 if("_blank" == "_self"){
#                    window.location = "https://www.clarin.com/suscripciones/landing.html?utm_source=clarin&utm_medium=header-promo&utm_campaign=HotSaleheader&utm_content=HotSale2019";
#                 }else{
#                     window.open("https://www.clarin.com/suscripciones/landing.html?utm_source=clarin&utm_medium=header-promo&utm_campaign=HotSaleheader&utm_content=HotSale2019","_blank");
#                 }
#              }, 200);
#          });
#
#
#         if($(window).outerHeight(true) < 560)
#             $('.dropdown-menu').css({'height':$(window).outerHeight(true)});
#
#         $('.container-submenu').add('.dropdown-menu').on('click', function(e){
#             e.stopImmediatePropagation();
#         });
#
#         $('.dropdown-menu .close').dropdown('toggle');
#
#         $('.navbar-nav li.dropdown').on('shown.bs.dropdown', function(){
#             $('header .menu-overlay').show();
#             $('.navbar-nav .nav-item').hide();
#             $('.nav-right .search').hide();
#             $('.nav-right .pase-sticky').hide();
#             $('.navbar-nav .isologo').hide();
#             $('html').css({'overflow':'hidden'});
#         });
#
#         $('.navbar-nav li.dropdown').on('hidden.bs.dropdown', function(){
#             $('header .menu-overlay').hide();
#             $('.navbar-nav .nav-item').css({'display':'block'});
#             $('.nav-right .search').css({'display':'block'});
#             if($('.header-content').find('nav.nav-st').length > 0){
#                 if($('.pase-sticky').length > 0)
#                     $('.pase-sticky').css({'display':'block'});
#                 if($('ul.navbar-nav li.isologo').length > 0)
#                     $('ul.navbar-nav li.isologo').css({'display':'block'});
#             }
#             $('html').css({'overflow':'initial'});
#         });
#
#
#         //Desplegable Pase
#         var toggle = false;
#         $(".pase-module .pase_LoggedIn").click(function(){
#             if(!toggle) {
#                 $(".pase-module .opciones.subnav").slideDown(300);
#                 toggle = true;
#             } else {
#                 $(".pase-module .opciones.subnav").slideUp(300);
#                 toggle = false;
#             }
#         });
#         //Fin deplegable Pase
#
#         //Menú Desplegable
#         $('.toggle-icon').on('click', function(e){
#             e.stopImmediatePropagation();
#             var thisElm = this;
#             var elmsDesplegados = $('.subsections-col:visible');
#
#             if($(thisElm).hasClass('open')){
#                 $(thisElm).removeClass('open');
#                 $(thisElm).closest('li').find('ul').slideUp(300);
#                 return false;
#             }
#
#             if(elmsDesplegados.length > 0) {
#                 $('.toggle-icon').removeClass('open');
#                 elmsDesplegados.slideUp(200, function(){
#                     desplegarMenu(thisElm);
#                 });
#             } else {
#                 desplegarMenu(thisElm);
#             }
#         });
#
#         function desplegarMenu(elm){
#             var classSection = $(elm).attr('class').split(" ")[1];
#             $(".subsections-col."+classSection).slideDown(300);
#             $(elm).addClass('open');
#         }
#         //Fin desplegable
#
#         var hasNotUlChild= $('.dropdown-menu .columna .section-name').not(':has("ul")');
#         hasNotUlChild.find('.toggle-icon').hide();
#
#         $('.dropdown-menu .columna').last().addClass('last');
#
#     });
#
#     $("#buscarForm").submit(function(e) {
#         e.preventDefault();
#         var val = $("#search_text").val();
#         if (val != "") {
#             window.location.assign("/buscador/?q=" + encodeURIComponent(val));
#         }
#     });
#
# </script>
# </header>
# <div class="banner-border">
# <div class="adv megaexpandible">
# <div id="epl_expandable_div"></div>
# <div>
# <div class="ad-slot" data-adtype="horizontal1" id="horizontal1"></div><!-- 1559452068 S -->
# </div>
# </div>
# </div>
# <!-- CALCCSS -->
# <script type="text/javascript">
# 	// Refresco de página - home
#         refresh_on = true;
#
#         function refresh_Play(){
#             metricsRefresh(5);
#         }
#
#         refresh_Play();
# </script>
# <div class="content home">
# <div class="container father" data-classes="container" data-name="container_father" data-type="container_father">
# <div class="container" data-classes="container  " data-name="contA" data-type="container">
# <div class="top-head">
# <div class="row bb-container bb-moduleId_v3_row_mod_201941458510798" data-count="12">
# <div class="border box col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p" data-classes="border box col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p" data-name="content" data-size-h="1" data-size-w="2">
# <article class="content-nota list-format twoxone_foto_small">
# <a href="/politica/presos-sufren-infortunios-carcel-esperanzan-salir-gana-alberto_0_nT2LVNJjF.html" target="_self">
# <div class="mt">
# <p class="volanta">Corrupción</p>
# <h1>Presos K: sufren infortunios en la cárcel pero se esperanzan con salir si gana Alberto Fernández</h1>
# </div>
# <div class="mg">
# <div class="pull-left txt">
# <p class="summary">Los ex funcionarios y empresarios detenidos intercambian información y creen que si el oficialismo pierde su situación judicial mejorará.</p>
# </div>
# <div class="wrap-figure">
# <figure id="imgmod_201956951314672">
# <img alt="Presos K: sufren infortunios en la cárcel pero se esperanzan con salir si gana Alberto Fernández" class="img-responsive intelResolution lazyload" data-big="https://images.clarin.com/2019/05/08/rKdhtjlWH_290x140__1.jpg" data-small="https://images.clarin.com/2019/05/08/rKdhtjlWH_290x140__1.jpg" src="https://images.clarin.com/collections/static/lazy_square.svg"/>
# </figure>
# </div>
# </div>
# <div class="data-txt">
# <a href="/politica/" target="_self"><p class="section">Política</p></a>
# <p class="author" onclick="window.open('/autor/nicolas-winazki.html','_blank');" style="cursor: pointer;">Nicolás Wiñazki</p>
# </div>
# </a>
# </article>
# </div>
# <div class="border box col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-classes="border box col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-name="content" data-size-h="1" data-size-w="1">
# <article class="visual content-nota onexone_visual txt-bottom list-format">
# <figure id="imgmod_201956877191416">
# <div class="wrap-img">
# <a href="/opinion/tio-alberto-idolo-groenlandia_0_hV6Sduti3.html" target="_self"><img alt="Tío Alberto" class="img-responsive intelResolution lazyload" data-big="https://images.clarin.com/2016/12/27/Byl4QU3yBg_290x290__3.jpg#1555207187091" data-small="https://images.clarin.com/2016/12/27/Byl4QU3yBg_290x290__3.jpg#1555207187091" src="https://images.clarin.com/collections/static/lazy_square.svg"/></a>
# </div>
# <div class="mt">
# <div class="max-h">
# <a href="/opinion/tio-alberto-idolo-groenlandia_0_hV6Sduti3.html" target="_self"><p class="volanta">Humor Político</p></a>
# <a href="/opinion/tio-alberto-idolo-groenlandia_0_hV6Sduti3.html" target="_self"><h3>Tío Alberto, un ídolo en Groenlandia</h3></a>
# </div>
# <div class="data-txt">
# <a href="/opinion/" target="_self"><p class="section">Opinión</p></a>
# <p class="author" onclick="window.open('/autor/alejandro-borensztein.html','_blank');" style="cursor: pointer;">Alejandro Borensztein</p>
# </div>
# </div>
# </figure>
# </article>
# </div>
# <div class="border box col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-classes="border box col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-name="content" data-size-h="1" data-size-w="1">
# <article class="content-nota onexone_foto list-format">
# <a href="/politica/axel-kicillof-mostro-veronica-magario-defiende-decreto-vidal_0_uhmWZdl-3.html" target="_self">
# <div class="wrap-figure">
# <figure id="imgmod_201956477308753">
# <img alt="Kicillof se mostró con Magario y se defiende con un decreto de Vidal" class="img-responsive intelResolution lazyload" data-big="https://images.clarin.com/2019/05/31/kP06-mQ3R_290x140__1.jpg" data-small="https://images.clarin.com/2019/05/31/kP06-mQ3R_290x140__1.jpg" src="https://images.clarin.com/collections/static/lazy_square.svg"/>
# </figure>
# </div>
# <div class="mt">
# <a href="/politica/axel-kicillof-mostro-veronica-magario-defiende-decreto-vidal_0_uhmWZdl-3.html" target="_self"><p class="volanta">El ring bonaerense</p></a>
# <a href="/politica/axel-kicillof-mostro-veronica-magario-defiende-decreto-vidal_0_uhmWZdl-3.html" target="_self"><h3>Kicillof se mostró con Magario y se defiende con un decreto de Vidal</h3></a>
# </div>
# <div class="data-txt">
# <a href="/politica/" target="_self"><p class="section">Política</p></a>
# <p class="author" onclick="window.open('/autor/pablo-ibanez.html','_blank');" style="cursor: pointer;">Pablo Ibáñez</p>
# </div>
# </a>
# </article>
# </div>
# <div class="border box col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-classes="border box col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-name="content" data-size-h="1" data-size-w="1">
# <article class="visual content-nota onexone_visual txt-bottom list-format">
# <figure id="imgmod_201956151634494">
# <div class="wrap-img">
# <a href="/opinion/estrategia-cristina-evitar-segunda-vuelta_0_jBpPhW-8Z.html" target="_self"><img alt="Las dudas de Massa" class="img-responsive intelResolution lazyload" data-big="https://images.clarin.com/2019/05/08/gy3OOyfUL_290x290__1.jpg" data-small="https://images.clarin.com/2019/05/08/gy3OOyfUL_290x290__1.jpg" src="https://images.clarin.com/collections/static/lazy_square.svg"/></a>
# </div>
# <div class="mt">
# <div class="max-h">
# <a href="/opinion/estrategia-cristina-evitar-segunda-vuelta_0_jBpPhW-8Z.html" target="_self"><p class="volanta">Del editor al lector</p></a>
# <a href="/opinion/estrategia-cristina-evitar-segunda-vuelta_0_jBpPhW-8Z.html" target="_self"><h3>Las dudas de Massa, el plan de Cristina</h3></a>
# </div>
# <div class="data-txt">
# <a href="/opinion/" target="_self"><p class="section">Opinión</p></a>
# <p class="author" onclick="window.open('/autor/ricardo-kirschbaum.html','_blank');" style="cursor: pointer;">Ricardo Kirschbaum</p>
# </div>
# </div>
# </figure>
# </article>
# </div>
# <div class="border box col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p bb-container bb-moduleId_v3_multiple_mod_201956263177376 special" data-classes="border box col-lg-3 col-md-4 col-sm-6 col-xs-12 special" data-name="containerMultiple" data-size-h="1" data-size-w="1">
# <div class="half col-lg-12 no-p" data-classes="half col-lg-12 no-p" data-name="content">
# <article class="content-nota list-format onexone_doble">
# <div class="wrap-figure">
# <a href="/sociedad/argentina-paises-trafican-pornografia-infantil-185-videos-dia_0_eJwibMQjy.html" target="_self">
# <figure id="imgmod_201956494904641">
# <img alt="Argentina" class="img-responsive intelResolution lazyload" data-big="https://images.clarin.com/2019/05/30/7fqREik0x_290x290__1.jpg" data-small="https://images.clarin.com/2019/05/30/7fqREik0x_110x110__1.jpg" src="https://images.clarin.com/collections/static/lazy_square.svg"/>
# </figure>
# </a>
# </div>
# <div class="mt">
# <a href="/sociedad/argentina-paises-trafican-pornografia-infantil-185-videos-dia_0_eJwibMQjy.html" target="_self">
# <p class="volanta">El caso del pediatra</p>
# <h2>Argentina, entre los países que más trafican pornografía infantil</h2>
# </a>
# </div>
# <div class="data-txt">
# <a href="/sociedad/" target="_self"><p class="section">Sociedad</p></a>
# <p class="author" onclick="window.open('/autor/emilia-vexler.html','_blank');" style="cursor: pointer;">Emilia Vexler</p>
# </div>
# </article>
# </div>
# <div class="half col-lg-12 no-p" data-classes="half col-lg-12 no-p" data-name="content">
# <article class="content-nota list-format onexone_doble">
# <div class="wrap-figure">
# <a href="/sociedad/pediatra-garrahan-trasladado-carcel-ezeiza-solo-visito-abogado_0_OYIBI886A.html" target="_self">
# <figure id="imgmod_201956853821359">
# <img alt="El pediatra fue trasladado a Ezeiza: el único que lo visitó fue su abogado" class="img-responsive intelResolution lazyload" data-big="https://images.clarin.com/2019/05/08/0FG2X145r_290x290__1.jpg" data-small="https://images.clarin.com/2019/05/08/0FG2X145r_110x110__1.jpg" src="https://images.clarin.com/collections/static/lazy_square.svg"/>
# </figure>
# </a>
# </div>
# <div class="mt">
# <a href="/sociedad/pediatra-garrahan-trasladado-carcel-ezeiza-solo-visito-abogado_0_OYIBI886A.html" target="_self">
# <p class="volanta">Solo y en silencio</p>
# <h2>El pediatra fue trasladado a Ezeiza: el único que lo visitó fue su abogado</h2>
# </a>
# </div>
# <div class="data-txt">
# <a href="/sociedad/" target="_self"><p class="section">Sociedad</p></a>
# <p class="author" onclick="window.open('/autor/mariano-gavira.html','_blank');" style="cursor: pointer;">Mariano Gavira</p>
# </div>
# </article>
# </div>
# </div>
# <!-- VISUAL -->
# <div class="border box col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p" data-classes="border box col-lg-6 col-md-8 col-sm-12 col-xs-12 no-p" data-name="content" data-size-h="1" data-size-w="2">
# <article class="visual content-nota twoxone_visual txt-bottom list-format">
# <a href="/deportes/tottenham-liverpool-final-champions-league-horario-tv-formaciones_0_9doQf84Al.html" target="_self">
# <figure id="imgmod_201956340378036">
# <div class="wrap-img">
# <img alt="El gigante está de vuelta: Liverpool gritó campeón" class="img-responsive intelResolution lazyload" data-big="https://images.clarin.com/2019/05/30/ncQ7I5OS9_600x290__1.jpg" data-small="https://images.clarin.com/2019/05/30/ncQ7I5OS9_340x340__1.jpg" src="https://images.clarin.com/collections/static/lazy_square.svg"/>
# </div>
# <div class="mt">
# <div class="max-h">
# <p class="volanta">Champions</p>
# <h2>El gigante está de vuelta: Liverpool gritó campeón</h2>
# </div>
# <div class="data-txt">
# <a href="/deportes/" target="_self"><p class="section">Deportes</p></a>
# </div>
# </div>
# </figure>
# </a>
# </article>
# </div>
# <div class="border box col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-classes="border box col-lg-3 col-md-4 col-sm-6 col-xs-12 no-p" data-name="content" data-size-h="1" data-size-w="1">
# <article class="content-nota onexone_foto list-format">
# <a href="/deportes/futbol-internacional/escandalo-brasil-acusan-neymar-violado-mujer_0_dSQMNg1wv.html" target="_self">
# <div class="wrap-figure">
# <figure id="imgmod_201956969740676">
# <img alt="¡Escándalo en Brasil! Acusan a Neymar de haber violado a una mujer" class="img-responsive intelResolution lazyload" data-big="https://images.clarin.com/2019/05/30/D_kpc8whI_290x140__3.jpg#1559434132752" data-small="https://images.clarin.com/2019/05/30/D_kpc8whI_290x140__3.jpg#1559434132752" src="https://images.clarin.com/collections/static/lazy_square.svg"/>
# </figure>
# </div>
# <div class="mt">
# <a href="/deportes/futbol-internacional/escandalo-brasil-acusan-neymar-violado-mujer_0_dSQMNg1wv.html" target="_self"><p class="volanta">A días de la Copa América</p></a>
# <a href="/deportes/futbol-internacional/escandalo-brasil-acusan-neymar-violado-mujer_0_dSQMNg1wv.html" target="_self"><h3>¡Escándalo en Brasil! Acusan a Neymar de haber violado a una mujer</h3></a>
# </div>
# <div class="data-txt">
# ...
# <script src="https://static.clarin.com/commons/js/wa.js" type="text/javascript"></script>
# <script src="https://static.clarin.com/commons/js/weizenbock.js?1.6" type="text/javascript"></script>
# <script id="despasescriptmo" src="https://static.clarin.com/static/DESPase/js/despasescriptmo.min.js?hash=3f2d853a4a3053105ef0f499610db5ca" type="text/javascript"></script>
# <script data-params="%7B%22siteName%22%3A%22clarin%22%2C%22siteId%22%3A%226906409%22%2C%22sectionId%22%3A%221%22%2C%22day%22%3A%22%22%2C%22month%22%3A%22%22%2C%22hours%22%3A%22%22%2C%22weekDay%22%3A%22%22%2C%22urlDate%22%3A%22%22%2C%22timestamp%22%3Anull%2C%22path%22%3A%22home.inicio%22%2C%22sourceModal%22%3A%22home%22%7D" defer="" id="directAppScript" src="https://static.clarin.com/static/DESDax/js/directAppHome.min.js?hash=793d26491f46ba80345faea4fb3e43ab" type="text/javascript"></script>
# <!-- Cxense script begin -->
# <script type="text/javascript">
#
#     $("#cargaItems").delay(2500).fadeIn();
#     var IdPase = "";
#     if (typeof getIdPase == 'function'){
#         IdPase = getIdPase();
#     }
#
#     if(typeof sas == "undefined"){
#         var adsblock = "si";
#     }else{
#         var adsblock = "no";
#     }
#
#     var cX = cX || {};
#     cX.callQueue = cX.callQueue || [];
#
#     var cXcustomParams = {'registered': false , 'pw_readable': true, 'userId': "",'sourcesite':'Clarín', 'adblock':adsblock,  'autorefresh':"YES", 'pagetype':'HOME'}
#
#     if (Number(IdPase) > 0 ) {
#         cX.callQueue.push(["addExternalId", {
#             "id": IdPase,
#             "type": "gca"
#         }]);
#
#         cXcustomParams.registered = true;
#         cXcustomParams.userId = IdPase;
#     }
#
#     cX.callQueue.push(["setSiteId", "9222353050745408878"]);
#     cX.callQueue.push(['setCustomParameters', cXcustomParams]);
#
#     cX.callQueue.push(["setEventAttributes",
#         { origin: 'gca-video', persistedQueryId: '872b6086b2066cab93ae25ef10cc058a38ee1a16'}
#     ]);
#     cX.callQueue.push(["sendPageViewEvent"]);
#
#     $("#loadingCxense").fadeOut(2500);
# </script>
# <!-- Cxense script end -->
# <script type="text/javascript">
#
#     var uiconf = "23448755";
#     var wid = "_102";
#     var cargo = false;
#
#     var settings = {
#         uiconf:uiconf,
#         wid:wid,
#         src:"https://vodgc.com/p/102/sp/10200/embedIframeJs/uiconf_id/23448755/partner_id/102"
#     };
#
#     $(document).bind('cbox_complete', function(){
#         settings.reload = true;
#         settings.embed_class = "kaltura_modal";
#         $.kLoader(settings);
#         settings.embed_class = "kaltura_player";
#         $.kLoader(settings);
#     });
#     $.kLoader(settings);
# </script>
# <script defer="" id="LOTCC_9602" onload="_cc9602.bcp();" src="//tags.crwdcntrl.net/c/9602/cc.js?ns=_cc9602" type="text/javascript"> </script>
# <!-- Google Analytics -->
# <script>
#
#     function mergeObject(finalObject, fieldsObject){
#         /* merge manual */
#         if (Object.keys(fieldsObject).length > 0)
#             for (i = 0, len = Object.keys(fieldsObject).length; i < len; i++) {
#                 var key = Object.keys(fieldsObject)[i];
#                 finalObject[key] = fieldsObject[key];
#             }
#
#         return finalObject;
#     }
#
#     function getValueFromCookie(cookieName){
#         var reg = cookieName+'\\=([^\\;]+)';
#         var matches = document.cookie.match(new RegExp(reg));
#         return matches!=null && matches.length > 1 ? matches[1] : '';
#     }
#
#     function adblockFlag(){
#         return typeof window.canRunAds == "undefined" ? true : false;
#     }
#
#     function sendGAPageview(customParams){
#         customParams = customParams || {};
#         analyticsHitParams.hitType = "pageview";
#         var finalObject = mergeObject(analyticsHitParams, customParams);
#
#         try{
#             if(typeof(window.isPrivateMode) == "undefined")
#                 throw 'waiting bprivate';
#
#             finalObject['dimension6'] = window.isPrivateMode;
#             finalObject['dimension14'] = sasClarinHelper.getPaseCounter();
#             finalObject['dimension15'] = sasClarinHelper.getPaseStatusSW() ? "si" : "no";
#             sendGAHit(finalObject);
#
#         }catch(e){
#             setTimeout(function(){
#                 sendGAPageview(customParams);
#             }, 200);
#         }
#     }
#
#     function getDataSource() {
#         return window.innerWidth<720 ? 'mobile' : 'web';
#     }
#
#     function parse_query_string(query) {
#         var vars = query.split("&");
#         var query_string = {};
#         for (var i = 0; i < vars.length; i++) {
#             var pair = vars[i].split("=");
#             var key = decodeURIComponent(pair[0]);
#             key = key.toLowerCase();
#             var value = decodeURIComponent(pair[1]);
#             // If first entry with this name
#             if (typeof query_string[key] === "undefined") {
#                 query_string[key] = decodeURIComponent(value);
#                 // If second entry with this name
#             } else if (typeof query_string[key] === "string") {
#                 var arr = [query_string[key], decodeURIComponent(value)];
#                 query_string[key] = arr;
#                 // If third or later entry with this name
#             } else {
#                 query_string[key].push(decodeURIComponent(value));
#             }
#         }
#         return query_string;
#     }
#
#     function getCampaign() {
#         var parameters = parse_query_string(location.search.slice(1));
#
#         if (typeof parameters.kw_campaign != "undefined" ) {
#             return parameters.kw_campaign;
#         }
#         if (typeof parameters.utm_campaign != "undefined" ) {
#             return parameters.utm_campaign;
#         }
#         return -2;
#     }
#
#
#     /**
#      * Ej: { hitType: 'event', eventCategory: 'Videos', eventAction: 'play', eventLabel: 'Kaltura' }
#      * @param fieldsObject object
#      */
#    /* function sendGAHit(fieldsObject, mergeWithGeneralParams){
#         fieldsObject = fieldsObject || {};
#         mergeWithGeneralParams = mergeWithGeneralParams || false;
#
#         var finalObject = {hitType: 'pageview'};
#
#         if(mergeWithGeneralParams)
#             finalObject = mergeObject(finalObject, analyticsHitParams);
#
#         finalObject = mergeObject(finalObject, fieldsObject);
#
#         if (fieldsObject.hitType == 'event') {
#             var dimensionsObject = {};
#             for (let [key, value] of Object.entries(fieldsObject)) {
#                 if (key.startsWith("dimension")) {
#                     dimensionsObject[key] = value;
#                 }
#                 if (key == "share_url") {
#                     dimensionsObject["dimension35"] = value;
#                 }
#                 if (key == "duration") {
#                     dimensionsObject["dimension36"] = value/1000;
#                 }
#             }
#             ga('send', 'event',
#                     'Video',
#                     fieldsObject.action.toLowerCase(),
#                     fieldsObject.content_id + " - " + fieldsObject.name,
#                     dimensionsObject
#             );
#         } else {
#             ga('send', finalObject);
#         }
#     }
# */
#     function sendGAHit(fieldsObject, mergeWithGeneralParams){
#         fieldsObject = fieldsObject || {};
#         mergeWithGeneralParams = mergeWithGeneralParams || false;
#
#         var finalObject = {hitType: 'pageview'};
#
#         if (!Object.entries) {
#             Object.entries = function (obj) {
#                 var ownProps = Object.keys(obj),
#                         i = ownProps.length,
#                         resArray = new Array(i);
#
#                 while (i--)
#                     resArray[i] = [ownProps[i], obj[ownProps[i]]];
#                 return resArray;
#             };
#         }
#
#         if(mergeWithGeneralParams)
#             finalObject = mergeObject(finalObject, analyticsHitParams);
#
#         finalObject = mergeObject(finalObject, fieldsObject);
#
#         if (fieldsObject.hitType == 'event') {
#             var dimensionsObject = {};
#             try {
#                 for (let [key, value] of Object.entries(fieldsObject)) {
#                     if (key.startsWith("dimension")) {
#                         dimensionsObject[key] = value;
#                     }
#                 }
#
#                 if(typeof fieldsObject.eventCategory == "undefined" || fieldsObject.eventCategory == "") throw "valor obligatorio";
#                 if(typeof fieldsObject.eventAction == "undefined" || fieldsObject.eventAction == "") throw "valor obligatorio";
#                 ga('send', 'event',
#                     fieldsObject.eventCategory,
#                     fieldsObject.eventAction,
#                     fieldsObject.eventLabel,
#                     dimensionsObject
#                 );
#             }
#             catch(err){
#
#             }
#         } else {
#             ga('send', finalObject);
#         }
#     }
#
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     detectPrivateMode(function (isPrivateMode) {
#         window.isPrivateMode = isPrivateMode ? 1 : 0;
#     });
#
#     var analyticsHitParams = {};
#     ga('create', 'UA-4436008-9', 'auto', {'allowAnchor': true});
#
#     $(document).on('hit.GA', function(e) {
#         var _weizenbockUser = WAuth.getUserSync();
#         analyticsHitParams = {
#             dataSource: getDataSource(),
#             userId: (_weizenbockUser && (typeof _weizenbockUser.uid !== 'undefined' ) && ! isNaN( _weizenbockUser.uid) ) ? _weizenbockUser.uid: "",
#             dimension1: (_weizenbockUser && (typeof _weizenbockUser.uid !== 'undefined' ) && ! isNaN( _weizenbockUser.uid) ) ? _weizenbockUser.uid: "-2",
#             dimension2: "clarin",
#             dimension3: adblockFlag() ? "si" : "no",
#             dimension4: "-2",
#             dimension5: "home.inicio",
#             dimension7: refreshChecker.isAutorefresh(),
#             dimension8: "2019",
#             dimension9: "06",
#             dimension10: "02",
#             dimension11: "01:11",
#             dimension12: "domingo",
#             dimension13: document.title,
#             dimension14: "",
#             dimension15: "",
#             dimension16: "no",
#             dimension17: "no",
#             dimension18: "no",
#             dimension19: "-2",
#             dimension20: sasClarinHelper.getTemperatura() ? sasClarinHelper.getTemperatura() : "-2",
#             dimension21: sasClarinHelper.getAudiencia("-2"),
#             dimension22: (_weizenbockUser && (typeof _weizenbockUser.genero !== 'undefined' )) ? _weizenbockUser.genero : "-2",
#             dimension23: (_weizenbockUser && (typeof _weizenbockUser.fechaNacimiento !== 'undefined')) ? sasClarinHelper.getAge(_weizenbockUser.fechaNacimiento) : "-2",
#             dimension24: "home",
#             dimension25: "-2",
#             dimension26: sasClarinHelper.getTipoSuscripcion("-2"),
#             dimension27: sasClarinHelper.getTipoLector(),
#             dimension31: sasClarinHelper.getPaywallChoque(),
#             dimension41: "-2",
#             dimension42: getCampaign()
#         };
#
#         sendGAPageview();
#     });
# </script>
# <!-- End Google Analytics -->
# <!-- Begin BlueKai Tag -->
# <iframe frameborder="0" height="0" name="__bkframe" src="about:blank" style="display:none;position:absolute;clip:rect(0px 0px 0px 0px)" width="0"></iframe>
# <script src="//tags.bkrtx.com/js/bk-coretag.js" type="text/javascript"></script>
# <script type="text/javascript">
#     bk_allow_multiple_calls=true;
#     bk_use_multiple_iframes=true;
#     bk_is_debug=true;
#
#     function sendBlueKai(){
#         try{
#
#             var GDPRv;
#
#             if(typeof $.cookie("cookieconsent_status") == "undefined"){
#                 GDPRv = "-2";
#             }else{
#                 if($.cookie("cookieconsent_status") == "deny"){
#                     GDPRv = "0";
#                 }
#                 if($.cookie("cookieconsent_status") == "allow"){
#                     GDPRv = "1";
#                 }
#             }
#
#             if(typeof(window.WAuth) == "undefined")
#                 throw 'waiting WAuth';
#
#             if(typeof(window.isPrivateMode) == "undefined")
#                 throw 'waiting bprivate';
#
#             var _weizenbockUser = WAuth.getUserSync();
#             if(_weizenbockUser){
#                 bk_addEmailHash(_weizenbockUser.email);
#             }else{
#                 bk_addEmailHash("-2");
#             }
#
#             bk_addPageCtx('bajada', "-2");
#             bk_addPageCtx('kw_ck', GDPRv);
#             bk_addPageCtx('section', 'home');
#             bk_addPageCtx('tipo_pagina', 'home');
#             bk_addPageCtx('ns_site', 'clarin');
#             bk_addPageCtx('name', 'home.inicio');
#             bk_addPageCtx('ET_multimedia', '-2');
#             bk_addPageCtx('kw_referrer', [document.referrer]);
#             bk_addPageCtx('keywords', []);
#             bk_addPageCtx('tags', []);
#             bk_addPageCtx('bprivate', window.isPrivateMode);
#             bk_addPageCtx('idPase', getValueFromCookie('idPase')=='' ? "-2" : getValueFromCookie('idPase'));
#             bk_addPageCtx('pase_sexo', _weizenbockUser ? _weizenbockUser.genero : "-2");
#             bk_addPageCtx('pase_edad', _weizenbockUser ? sasClarinHelper.getAge(_weizenbockUser.fechaNacimiento) : "-2");
#             bk_addPageCtx('contador_gral', sasClarinHelper.getPaseCounter());
#             bk_addPageCtx('block_LW', sasClarinHelper.getPaseStatusSW() ? "si" : "no");
#             bk_addPageCtx('block_PW', 'no');
#             bk_addPageCtx('tipo_suscriptor', sasClarinHelper.getTipoSuscripcion("-2"));
#             bk_addPageCtx('tipo_lector', sasClarinHelper.getTipoLector());
#             bk_addPageCtx('kw_pw_counter', sasClarinHelper.getPaseCounter());
#             bk_addPageCtx('kw_choque', sasClarinHelper.getPaywallChoque());
#             bk_doJSTag(66466, 1);
#         } catch(e) {
#             setTimeout(function(){
#                 sendBlueKai();
#             }, 200);
#         }
#     }
#     sendBlueKai();
# </script>
# <!-- End BlueKai Tag -->
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
#     var js, fjs = d.getElementsByTagName(s)[0];
#     if (d.getElementById(id)) return;
#     js = d.createElement(s); js.id = id;
#     js.src = "//connect.facebook.net/es_ES/sdk.js#xfbml=1&version=v2.4&appId=173748289375719";
#     fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-J5TM" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-J5TM');</script>
# <!-- End Google Tag Manager -->
# <script type="text/javascript">
# window.onload = function () {
#     optaLoader.findWidget();
# }
# </script>
# <script type="text/javascript">
#       var _sf_async_config = _sf_async_config || {};
#       /** CONFIGURATION START **/
#       _sf_async_config.authors = 'clarin';
#
#       _cbq = window._cbq = (window._cbq || []);
#       // acct : Guest:  'anon' || Registered: 'lgdin' || Subscriber: 'paid'
#       _cbq.push(['_acct', getChartbeatUserType()]);
#       /** CONFIGURATION END **/
#       function loadChartbeat() {
#           window._sf_endpt = (new Date()).getTime();
#           var e = document.createElement('script');
#           e.setAttribute('language', 'javascript');
#           e.setAttribute('type', 'text/javascript');
#           e.setAttribute('src', '//static.chartbeat.com/js/chartbeat.js');
#           document.body.appendChild(e);
#       }
#       loadChartbeat();
# </script>
# </body>
# </html>
