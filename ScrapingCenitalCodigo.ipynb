# %%
import requests
from bs4 import BeautifulSoup
import time
import datetime
import json
import os

class Cenital:
    
    myname = "Cenital"
    savefolder = "./dataCenital/"
    rawdata = "raw/"
    
    class Home:
    
        url = "https://www.cenital.com/"
       
    
        def __init__ (self):
            self.page = requests.get(self.url)
            if self.page.status_code != 200:
                print (self.page.status_code)
            else:
                print ("Home de " + Cenital.myname + " descargado con exito.")
            self.bpage = BeautifulSoup(self.page.content, 'html.parser')

        def printpretty(self):
            print(self.bpage.prettify())
            
        def getlistofnotes(self):
            info = Cenital.generateinfo("notasHome")
            # Buscamos con el class card-title todas las notas porque es lo unico que idententifica a todas las notas del home
            titulos = cenital.home.bpage.find_all(attrs={"class":"card-title"})
            for titulo in titulos:
                vinculo = titulo.find_all("a")
                assert len (vinculo) == 1, "error, se encontro mas de un titulo por nota"
                info [vinculo[0]['href']] = {}
                info [vinculo[0]['href']]["Url"] = Cenital.Home.url + vinculo[0]['href']
                info [vinculo[0]['href']]["Titulo"] = vinculo[0].string
            return info
            
    class Noticia:
        
        def __init__ (self,url):
            self.url = url
            self.page = requests.get(self.url)
            if self.page.status_code != 200:
                print (self.page.status_code)
            else:
                print ("Nota " + self.url + " descargada con exito.")
            self.bpage = BeautifulSoup(self.page.content, 'html.parser')

        def printpretty(self):
            print(self.bpage.prettify())
        
    def gethome(self):
        self.home = self.Home()
        
    def generateinfo (name):
        info = {}
        info["metadata"] = {}
        info["metadata"]["timestampofsearch"] = datetime.datetime.now().timestamp()
        info["metadata"]["timeofsearch"] = datetime.datetime.fromtimestamp(info["metadata"]["timestampofsearch"]).isoformat()
        info["metadata"]["filename"] = Cenital.savefolder + Cenital.rawdata + datetime.datetime.fromtimestamp(info["metadata"]["timestampofsearch"]).strftime("%Y-%m-%d-%H-%M") + "_" + name + ".json"
        return info
        
    def removemetadata(info):
        del info["metadata"]
        
    def saveinfo(info):
        with open(info["metadata"]["filename"], 'w') as f:
            json.dump(info, f)
            
    
        
        
    # Inicializa las carpetas si no existen
    if not os.path.exists(savefolder):
        os.makedirs(savefolder)
    if not os.path.exists(savefolder+rawdata):
        os.makedirs(savefolder+rawdata)

# %%
cenital = Cenital()
cenital.gethome()
listadenotas = cenital.home.getlistofnotes()
Cenital.removemetadata(listadenotas)
#for key, data in listadenotas.items():
noticia = Cenital.Noticia(list(listadenotas.values())[1]["Url"])
# Out:
# Home de Cenital descargado con exito.
# Nota https://www.cenital.com/2019/06/15/de-donde-vienen-los-dolares/63771 descargada con exito.

# %%
noticia.printpretty()
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <base href="https://www.cenital.com/"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
#   <meta content="Cenital" name="author"/>
#   <link href="favicon.ico" rel="icon" type="image/png"/>
#   <title>
#    De dónde vienen los dólares
#   </title>
#   <meta content="La escasez crónica de esta divisa es uno de los problemas centrales de la economía argentina." name="description"/>
#   <link href="https://www.cenital.com/2019/06/15/de-donde-vienen-los-dolares/63771" rel="canonical">
#    <meta content="https://www.cenital.com/2019/06/15/de-donde-vienen-los-dolares/63771" property="og:url">
#     <meta content="article" property="og:type">
#      <meta content="De dónde vienen los dólares" property="og:title">
#       <meta content="La escasez crónica de esta divisa es uno de los problemas centrales de la economía argentina." property="og:description">
#        <meta content="https://www.cenital.com/contenido/noticias/original/1560631005.jpeg" property="og:image">
#         <meta content="summary_large_image" name="twitter:card"/>
#         <meta content="@cenitalcom" name="twitter:site"/>
#         <meta content="@cenitalcom" name="twitter:creator"/>
#         <meta content="De dónde vienen los dólares" name="twitter:title"/>
#         <meta content="La escasez crónica de esta divisa es uno de los problemas centrales de la economía argentina." name="twitter:description"/>
#         <meta content="https://www.cenital.com/contenido/noticias/original/1560631005.jpeg" name="twitter:image"/>
#         <!-- CCS GENERAL -->
#         <link href="css/bootstrap.min.css" rel="stylesheet"/>
#         <link href="css/custom-2.css?v=1.61" rel="stylesheet"/>
#         <link href="css/basic-styles.css?v=1.61" rel="stylesheet"/>
#         <link href="css/personal-styles.css?v=1.61" rel="stylesheet"/>
#         <link href="css/casas-de-hoy.css?v=1.61" rel="stylesheet"/>
#         <link href="css/card.css?v=1.61" rel="stylesheet"/>
#         <link href="css/modulos.css?v=1.61" rel="stylesheet"/>
#         <link href="css/polsk-styles.css?v=1.61" rel="stylesheet"/>
#         <!-- CCS FUENTES -->
#         <link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700" rel="stylesheet"/>
#         <link href="https://fonts.googleapis.com/css?family=Noticia+Text&amp;display=swap" rel="stylesheet"/>
#         <link href="font-awesome-4.4.0/css/font-awesome.min.css" rel="stylesheet" type="text/css">
#          <!-- OWL CAROUSEL -->
#          <link href="js/owl-carousel/owl.carousel.css?v=1.61" rel="stylesheet"/>
#          <link href="js/owl-carousel/owl.theme.default.min.css" rel="stylesheet"/>
#          <!-- OTHER CAROUSEL -->
#          <link href="css/personal-carousel.css?v=1.61" rel="stylesheet"/>
#          <!-- MARQUESINA -->
#          <link href="css/jquery.smarticker.min.css" rel="stylesheet">
#           <link href="css/marquesina.css?v=1.61" rel="stylesheet">
#            <!-- NEWS BOX -->
#            <link href="css/site.css?v=1.61" rel="stylesheet" type="text/css">
#             <!-- BUSCADOR MENU
# <link href="css/search-styles.css?v=1.61" rel="stylesheet" type="text/css" />-->
#             <!-- BUSCADOR GALERIA -->
#             <link href="css/blueimp-gallery.min.css" rel="stylesheet"/>
#             <link href="css/bootstrap-image-gallery.css?v=1.61" rel="stylesheet"/>
#             <link href="css/sonar.css?v=1.61" rel="stylesheet"/>
#             <link href="manifest.json?v=1.61" rel="manifest"/>
#             <!-- Global site tag (gtag.js) - Google Analytics -->
#             <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-33282694-18">
#             </script>
#             <script>
#              window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-33282694-18');
#             </script>
#             <style>
#              .detalle-noticia p{
#     /*margin-bottom:0px;*/
# }
#
# .contexto{
# 	padding: 20px;
# 	background-color:#f4f4f4;
# 	margin-bottom: 40px;
# }
#
# .contexto h2 {
#     font-size: 16px;
#     font-weight: 600;
# 	margin-bottom:15px;
# }
#
# .contexto h2 a {
#     color: #ff312e;
# 	cursor:pointer;
# }
#
# .contexto p {
#     font-size: 13.4px;
# 	line-height:20px;
# 	color: #666;
# }
#
# .cerrar-nota{
#     display: inline-block;
#     /* margin-bottom: -100px; */
#     position: absolute;
# 	cursor:pointer;
# 	/*margin-top:15px;*/
# 	height:44px;
# 	width:44px;
# 	background-image:url(img/cerrar-nota-mas.png);
# 	background-position:center;
# 	-webkit-transition: 0.5s;
# 	-moz-transition: 0.5s;
# 	-ms-transition: 0.5s;
# 	transition: 0.5s;
# }
#
# .cerrar-nota.uncheck {
# 	background-image:url(img/cerrar-nota.png);
# 	-webkit-transition: 0.5s;
# 	-moz-transition: 0.5s;
# 	-ms-transition: 0.5s;
# 	transition: 0.5s;
# }
#
# .cerrar-nota.check {
# 	background-image:url(img/cerrar-nota.png);
# 	-webkit-transition: 0.5s;
# 	-moz-transition: 0.5s;
# 	-ms-transition: 0.5s;
# 	transition: 0.5s;
# }
#
#
#
# .titulo-new{
#     background-color: white;
#     padding-top: 30px;
#     padding-right: 40px;
#     padding-bottom: 15px;
#     margin-top: -45px;
#     width: 76%;
#     border-radius: 0px 7px;
# }
#
# @media (max-width: 992px) {
# .titulo-new{
#     background-color: white;
#     padding-top: 10px;
#     padding-right: 0px;
#     padding-bottom: 10px;
#     margin-top: 0px;
#     width: auto;
#     border-radius: 0px 0px;
# 	font-size:22px !important;
# }
# }
#
# .link-autor{
#     font-size: 14px; font-weight: bold;
# }
#
# .periodista-email, .periodista-redes{
#     font-weight: normal;
# }
# .detalle-noticia p, .detalle-noticia div{
#     line-height: 150%;
# }
#             </style>
#             <style>
#              .carousel_noticias_flex .owl-stage {
# 	    display: flex;
# 	}
# 	.carousel_noticias_flex	.owl-item {
# 		display: flex;
# 		flex: 1 0 auto;
# 	}
# 	.carousel_noticias_flex	.owl-item .item {
# 	    display: flex;
# 	}
#             </style>
#            </link>
#           </link>
#          </link>
#         </link>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </link>
#  </head>
#  <body class="auto-padd">
#   <input name="pagina_publicidades" type="hidden" value="Amplia-Noticia"/>
#   <div id="fb-root">
#   </div>
#   <script>
#    (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/es_LA/sdk.js#xfbml=1&version=v2.6";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#   </script>
#   <section class="">
#    <input name="pagina_publicidades" type="hidden" value="Amplia-Noticia"/>
#    <div class="navbar navbar-default navbar-fixed-top normal yamm" role="navigation">
#     <div class="container">
#      <div class="navbar-header">
#       <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#        <span class="sr-only">
#         navegación
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#       <p class="visible-xs pull-right boton-carrito">
#        <a class="hidden-sm hidden-lg hidden-md negro boton-menu-top">
#         <img src="img/search-xs.png"/>
#        </a>
#       </p>
#       <a class="navbar-brand" href="index.html">
#        <img src="img/logo.png"/>
#       </a>
#      </div>
#      <div class="navbar-collapse collapse">
#       <ul class="nav navbar-nav navbar-left-paul">
#        <li class="dropdown">
#         <a class="dropdown-toggle" data-toggle="dropdown" href="#" id="dLabel">
#          Argentina
#          <span class="caret">
#          </span>
#         </a>
#         <ul class="dropdown-menu">
#          <li>
#           <a href="politica.html">
#            Política
#           </a>
#          </li>
#          <li>
#           <a href="economia.html">
#            Economía
#           </a>
#          </li>
#          <li>
#           <a href="judiciales.html">
#            Judiciales
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="mundo.html">
#          Mundo
#         </a>
#        </li>
#        <li>
#         <a href="opinion.html">
#          Opinión
#         </a>
#        </li>
#        <li class="dropdown">
#         <a class="dropdown-toggle" data-toggle="dropdown" href="#" id="dLabel">
#          Más
#          <span class="caret">
#          </span>
#         </a>
#         <ul class="dropdown-menu">
#          <li>
#           <a href="tecnologia.html">
#            Tecnología
#           </a>
#          </li>
#          <li>
#           <a href="newsletter.php">
#            Newsletters
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="hidden-xs hidden-md hidden-lg">
#         <a class="boton-menu-top" style="cursor:pointer;">
#          <img src="img/search-xs.png"/>
#         </a>
#        </li>
#       </ul>
#       <span class="redes-head list-inline navbar-right hidden-xs hidden-sm">
#        <a class="social" href="https://www.facebook.com/Cenitalcom/" target="_blank">
#         <i class="fa fa-facebook">
#         </i>
#        </a>
#        <a class="social" href="https://twitter.com/cenitalcom" target="_blank">
#         <i class="fa fa-twitter">
#         </i>
#        </a>
#        <a class="social" href="https://www.instagram.com/cenitalcom/" target="_blank">
#         <img src="img/insta-icon.png" style="    margin-top: -4px;"/>
#        </a>
#        <a class="negro boton-menu-top" style="display: inline-block;margin: 2px;margin-left: 5px; cursor:pointer;">
#         <img src="img/search-xs.png"/>
#        </a>
#       </span>
#      </div>
#      <!--/.nav-collapse -->
#     </div>
#     <!--/.container-fluid -->
#     <div class="buy-search" style="display:none;background-color: #f9f9f9;">
#      <section class="padd-bot-top-10 bg-buscador">
#       <div class="container edit">
#        <div class="row">
#         <div class="col-lg-offset-2- col-lg-8- col-md-8- col-sm-6- col-xs-12">
#          <form action="resultados.php" method="get" name="buscar">
#           <div class="input-group">
#            <input class="form-control input-lg radius-none" name="q" placeholder="Buscar noticias dentro del sitio" style="font-size: small;
#     font-weight: 300;" type="text">
#             <div class="input-group-btn">
#              <button class="btn btn-default input-lg radius-none" type="submit">
#               <img src="img/lupita.png" width="17"/>
#              </button>
#             </div>
#            </input>
#           </div>
#          </form>
#         </div>
#        </div>
#        <!-- FIN ROW -->
#       </div>
#       <!-- FIN CONTAINER -->
#      </section>
#      <!-- FIN SECTION -->
#     </div>
#    </div>
#   </section>
#   <section class="padd-bot-top-20">
#    <div class="container">
#     <div class="row padding-top padding-bottom">
#      <div class="col-lg-10 col-md-10 col-sm-12 col-xs-12 amplia-nota-info">
#       <ul class="nav nav-tabs hidden" id="myTab" style="margin-bottom: 0px; border: 0px; position: absolute; top: 3px; left: 33px; background-color: transparent; z-index: 100;">
#        <li class="active">
#         <a aria-expanded="true" data-toggle="tab" href="#foto">
#          <i class="fa fa-camera-retro fa-lg">
#          </i>
#          FOTOS
#         </a>
#        </li>
#       </ul>
#       <div class="tab-content" id="myTabContent">
#        <div class="tab-pane fade active in" id="foto">
#         <div class="carousel slide transition-timer-carousel" data-ride="carousel" id="transition-timer-carousel">
#          <!-- Wrapper for slides -->
#          <div class="carousel-inner">
#           <div class="item active">
#            <img class="img-responsive" src="contenido/../contenido/noticias/original/1560631005.jpeg"/>
#           </div>
#          </div>
#          <!-- Controls -->
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="col-lg-2 col-md-2 col-sm-12 col-xs-12 hidden-sm hidden-xs" style="padding-top:8px;">
#       <p class="small gris">
#       </p>
#      </div>
#      <div class="col-lg-2 col-md-2 col-sm-12 col-xs-12 visible-sm visible-xs amplia-nota-info" style="padding-top:6px;">
#       <p class="small gris">
#       </p>
#      </div>
#      <div class="col-lg-10 col-md-10 col-sm-12 col-xs-12 amplia-nota-info">
#       <h2 class="card-title titulo titulo-lg titulo-new">
#        De dónde vienen los dólares
#       </h2>
#       <p class="fecha-interior hidden">
#        15/06/2019 17:06:00
#       </p>
#      </div>
#      <div class="col-lg-8 col-md-8 col-sm-12 col-xs-12 amplia-nota-info">
#       <p class="texto3" style="font-family: 'Noticia Text', serif; font-size: 20px; color: #555; line-height: 150%; ">
#        La escasez crónica de esta divisa es uno de los problemas centrales de la economía argentina.
#       </p>
#      </div>
#     </div>
#     <div class="row">
#      <!----------- CONTENIDO DE LA NOTA ------------>
#      <div class="col-lg-9 col-xs-12 amplia-nota-info">
#       <div class="row">
#        <div class="col-xs-12 padd-bot-10">
#         <p class="persona-nota">
#          <img class="img-circle pull-left" src="contenido/../contenido/periodistas/1559758143.jpg" style="margin-top: 7px;" width="44"/>
#          <span class="box-span">
#           <i>
#            <a class="link-autor negro" href="periodista-mara-ruiz-malec-54">
#             Mara Ruiz Malec
#            </a>
#           </i>
#           <br/>
#           <span class="periodista-redes negro">
#            15 de junio de 2019 17:06 hs
#           </span>
#           <br/>
#           <span class="periodista-email">
#            mara@cenital.com
#           </span>
#           <br class="visible-xs"/>
#           <i class="fa fa-twitter">
#           </i>
#           <a class="negro periodista-redes" href="https://twitter.com/marucha_rm" target="_blank">
#            @marucha_rm
#           </a>
#          </span>
#          <a class="mas-notas hidden" href="periodista-mara-ruiz-malec-54">
#           Ver más notas del periodista
#          </a>
#         </p>
#         <div class="share-buttons hidden-xs">
#          <!--<h5>Compartir</h5>-->
#          <div class="posts-shares">
#           <div class="social-shares clearfix">
#            <ul>
#             <li>
#              <a class="btn-facebook" href='javascript:window.open("https://www.facebook.com/sharer.php?u=https://www.cenital.com/2019/06/15/de-donde-vienen-los-dolares/63771", "_new", "width=600, height=400, top=100, left=100");' title="">
#               <i class="fa fa-facebook">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a class="btn-twitter" href='javascript:window.open("https://twitter.com/share?text=De dónde vienen los dólares&amp;url=https://www.cenital.com/2019/06/15/de-donde-vienen-los-dolares/63771&amp;via=cenitalcom", "_new", "width=600, height=400, top=100, left=100");' title="">
#               <i class="fa fa-twitter">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a class="btn-whatsapp" data-action="share/whatsapp/share" href="https://api.whatsapp.com/send?text=https://www.cenital.com/2019/06/15/de-donde-vienen-los-dolares/63771" target="_blank">
#               <i class="fa fa-whatsapp">
#               </i>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#         <!-- fin share -->
#        </div>
#        <div class="col-xs-12 visible-xs">
#         <ul class="list-unstyled list-inline text-center">
#          <li class="padd-bot-10">
#           <a class="btn btn-sm btn-facebook btn-block" href='javascript:window.open("https://www.facebook.com/sharer.php?u=https://www.cenital.com/2019/06/15/de-donde-vienen-los-dolares/63771", "_new", "width=600, height=400, top=100, left=100");' title="">
#            <i class="fa fa-facebook">
#            </i>
#           </a>
#          </li>
#          <li class="padd-bot-10">
#           <a class="btn btn-sm btn-twitter btn-block" href='javascript:window.open("https://twitter.com/share?text=&amp;url=https://www.cenital.com/2019/06/15/de-donde-vienen-los-dolares/63771", "_new", "width=600, height=400, top=100, left=100");' title="">
#            <i class="fa fa-twitter">
#            </i>
#           </a>
#          </li>
#          <li class="padd-bot-10">
#           <a class="btn btn-whatsapp btn-block btn-sm" data-action="share/whatsapp/share" href="https://api.whatsapp.com/send?text=https://www.cenital.com/2019/06/15/de-donde-vienen-los-dolares/63771" target="_blank">
#            <i class="fa fa-whatsapp">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-xs-12 padd-bot-20">
#        </div>
#        <div class="col-xs-12 padd-bot-10 detalle-noticia">
#         <p>
#          <span style="font-weight: bold;">
#           La loca carrera por los dólares
#          </span>
#          <br/>
#         </p>
#         <p>
#          La escasez crónica de dólares es uno de los principales, sino el principal, problema de la economía argentina. Esto es fácil de entender si consideramos la centralidad que tiene el dólar en la discusión económica de nuestro país. Usamos el dólar para comprar cosas importadas, para comprar insumos para producir localmente, para ahorrar y es una referencia ineludible para la formación de precios.
#         </p>
#         <p>
#          En esta infografía mostramos cómo se comportó la oferta y la demanda de dólares desde la salida de la convertibilidad. Sin embargo, antes de mirar los gráficos, conviene ingresar primero en el torbellino de los dólares. Agárrense el sombrero.
#         </p>
#         <p>
#          <span style="font-weight: bold;">
#           La oferta
#          </span>
#         </p>
#         <p>
#          La principal fuente de dólares de la economía argentina son las exportaciones de bienes. Las exportaciones son los bienes producidos en Argentina que se venden al exterior. Para tener una idea de la importancia de las exportaciones, estas son las proveedoras del 80% de los dólares que ingresaron a la Argentina entre 2004 y 2018.
#         </p>
#         <p>
#          Entre 2005 y 2011 el mundo atravesó lo que se denominó un boom de commodities, que no fue otra cosa que un fuerte aumento de los precios de las materias primas agrícolas, metalíferas y energéticas. Este boom ayudó a que las exportaciones argentinas tuvieran un buen desempeño en este período. Las causas de este fenómeno son variadas, pero una de las principales es el marcado crecimiento que experimentó la economía de China en este período.
#         </p>
#         <p>
#          Este proceso se vio interrumpido temporalmente en los años 2008/2009 por la llamada "crisis de las hipotecas" de Estados Unidos. Volvieron a crecer en 2010 y todo parecía volver a la "normalidad". Sin embargo, a partir de 2011 los precios de las materias primas empezaron a retroceder otra vez. A esto último se sumó la caída en la demanda de bienes producidos en Argentina debido a la crisis política y económica de Brasil -el principal socio comercial de nuestro país-. Estos factores hicieron que a partir de ese año las exportaciones hayan perdido impulso como fuente de dólares de la economía.
#         </p>
#         <p>
#          La segunda fuente de dólares en importancia es la prestación de servicios, dentro de los cuales se destacan los servicios empresariales, profesionales y técnicos y, en un segundo plano, el turismo, es decir, el gasto de turistas extranjeros en Argentina. Luego de los servicios se encuentra la llamada Inversión Extranjera Directa (IED), que son las inversiones en activos reales que empresas e individuos del exterior realizan en Argentina. La IED es la nube que tendría que haber dejado caer la famosa "lluvia de inversiones" que finalmente no se dio.
#         </p>
#         <p>
#          Finalmente, hay dos fuentes adicionales de dólares que son estrictamente financieras, que tuvieron un fuerte crecimiento desde que asumió Cambiemos a fines de 2015. Estos son los préstamos financieros, dentro de los cuales se incluyen las emisiones de deuda récord que realizó el gobierno en lo que va de su mandato, y las llamadas inversiones de cartera, o más coloquialmente "capitales golondrina", dentro de los cuales se destacan las inversiones de fondos del exterior para comprar instrumentos financieros locales, como las antiguas LEBAC. Esta fuente de dólares es la que sigue la máxima de "vive rápido y deja un bonito cadáver": así como provee de dólares en la buena, en la mala deja territorio arrasado. Esto es justamente lo que ocurrió en Argentina durante la crisis cambiaria del año pasado, período en el cual la oferta de dólares por inversión de cartera cambió de signo y se volvió negativa, transformándose en demanda de dólares.
#         </p>
#         <p>
#          Tanto el auge como la caída de estos flujos financieros puede visualizarse fácilmente en el gráfico de oferta de dólares.
#         </p>
#         <p>
#          <span style="font-weight: bold;">
#           La demanda
#          </span>
#         </p>
#         <p>
#          Así como las exportaciones son la principal fuente de dólares, las importaciones son el principal factor de demanda. Tal es así que un 65% de demanda total de dólares de la Argentina entre 2004 y 2018 estuvo destinada a pagar los bienes comprados al exterior. Las importaciones dependen en gran medida del nivel de actividad económica: cuando la economía crece las importaciones suben, y cuando la economía cae las importaciones caen. La economía argentina es muy dependiente de las compras del exterior. Tal es así que por cada punto que crece la economía argentina, las importaciones crecen aproximadamente en 3,5 puntos porcentuales.
#         </p>
#         <p>
#          El gobierno podría en principio tratar de moderar el crecimiento de las importaciones con impuestos y restricciones a la importación, aunque esta estrategia tiene sus límites. En primer término, porque hoy en día las normas internacionales imponen un tope al proteccionismo de los países, y segundo porque la economía argentina es altamente dependiente de la importación de bienes de capital e insumos necesarios para la producción nacional.
#         </p>
#         <p>
#          El segundo factor en importancia de demanda de dólares es la contratación de servicios, dentro de los cuáles se destacan los dólares que demandan los argentinos que viajan al exterior. En los últimos años, el turismo se transformó en un factor muy importante e inesperado de demanda de dólares. Para tener una idea, en 2018 se demandaron cerca de 20.000 millones de dólares para turismo y viajes, lo que "consumió" más del 30% de los dólares generados por las exportaciones argentinas al exterior. Con la devaluación y la recesión esta vía de escape perdió fuerza, pero sigue siendo muy importante.
#         </p>
#         <p>
#          El tercer factor en importancia, pero muy cerca de turismo y viajes, es la llamada Formación de Activos Externo (FAE), que no es otra cosa de la demanda de dólares para ahorrar ("atesorar" decimos los economistas). En Argentina hay una larga tradición de ahorro en moneda dura, que se ve reforzado cuando el tren de la economía argentina entra en el túnel de la incertidumbre. La FAE es lo que habitualmente se denomina "fuga de capitales", y generalmente es encabezada por los grandes inversores domésticos, que siempre son corridos de atrás por los pequeños ahorristas.
#         </p>
#         <p>
#          Entre 2011 y 2015 la FAE estuvo sujeta a una fuerte regulación por parte del gobierno. Esto se ve reflejado en la retracción de la barra verde del gráfico de demanda de dólares. Esta política fue muy criticada no solo por las mayores dificultades para acceder al "oro verde", sino también porque algunos/as economistas sostuvieron que cuando el gobierno ponía límites a la demanda, la oferta se retraía y los dólares que se ahorraban por un lado se perdían por otro. Con el cambio de gobierno la economía argentina se movió de un extremo al otro: la eliminación absoluta de las regulaciones a la compraventa de dólares terminó siendo un gran dolor de cabeza para Cambiemos en el epicentro de la crisis del año pasado.
#         </p>
#         <p>
#          Otro de los otros factores de demanda de dólares son las rentas. Las rentas son los pagos de intereses y utilidades que realiza Argentina al exterior. El pago de intereses es producto de que Argentina es deudora del resto del mundo, en gran medida gracias a la política de endeudamiento del actual gobierno. El pago de utilidades es consecuencia de la estructura productiva altamente extranjerizada que tiene nuestro país, que hace que periódicamente las empresas extranjeras busquen repatriar las ganancias obtenidas en Argentina. Es la contracara de la Inversión Extranjera Directa.
#         </p>
#         <p>
#          Finalmente, el último factor de demanda que reseñaremos aquí será, oh casualidad, la inversión de cartera que, como anticipamos cambia de color según la ocasión.
#         </p>
#         <p>
#          <span style="font-weight: bold;">
#           Argentina en el parque de diversiones
#          </span>
#         </p>
#         <p>
#          Como vimos, no hay una única fuente de oferta y demanda de dólares sino varias. Esto hace que el problema de la escasez de dólares de la economía argentina parezca difícil de solucionar, lo cual efectivamente es así. El actual gobierno pareció haber tomado el atajo de las fuentes financieras, pero se encontró con un callejón sin salida a la vuelta de la esquina. El desafío del próximo gobierno, sea cual fuere su signo político, será crear fuentes genuinas de generación de divisas que logren que la Argentina se empiece a bajar, de a poco, de la montaña rusa del dólar.
#         </p>
#         <p>
#          Ahora sí, ya pueden subirse y darle play.
#         </p>
#         <div class="flourish-embed" data&#45;src="story/39464">
#          <iframe frameborder="0" scrolling="no" src="https://public.flourish.studio/story/39464/embed?auto=1" style="width: 100%; height: 743px;">
#          </iframe>
#          <div class="flourish-credit" style="width:100%!important;margin:0 0 4px!important;text-align:right!important;font-family:Helvetica,sans-serif!important;color:#888!important;font-size:11px!important;font-weight:bold!important;font-style:normal!important;-webkit-font-smoothing:antialiased!important;box-shadow:none!important;">
#           <a href="https://public.flourish.studio/story/39464/?utm_source=showcase&amp;utm_campaign=story/39464" style="display:inline-block!important;text-decoration:none!important;font:inherit!important;color:inherit!important;border:none!important;margin:0 5px!important;box-shadow:none!important;" target="_top">
#            <img alt="Flourish logo" src="https://public.flourish.rocks/resources/bosh.svg" style="font:inherit!important;width:auto!important;height:12px!important;border:none!important;margin:0 2px 0!important;vertical-align:middle!important;display:inline-block!important;box-shadow:none!important;"/>
#            <span style="font:inherit!important;color:#888!important;vertical-align:middle!important;display:inline-block!important;box-shadow:none!important;">
#             A Flourish data visualisation
#            </span>
#           </a>
#          </div>
#          <iframe frameborder="0" scrolling="no" src="https://public.flourish.studio/story/39464/embed?auto=1" style="width: 100%; height: 743px;">
#          </iframe>
#          <div class="flourish-credit" style="width:100%!important;margin:0 0 4px!important;text-align:right!important;font-family:Helvetica,sans-serif!important;color:#888!important;font-size:11px!important;font-weight:bold!important;font-style:normal!important;-webkit-font-smoothing:antialiased!important;box-shadow:none!important;">
#           <a href="https://public.flourish.studio/story/39464/?utm_source=showcase&amp;utm_campaign=story/39464" style="display:inline-block!important;text-decoration:none!important;font:inherit!important;color:inherit!important;border:none!important;margin:0 5px!important;box-shadow:none!important;" target="_top">
#            <img alt="Flourish logo" src="https://public.flourish.rocks/resources/bosh.svg" style="font:inherit!important;width:auto!important;height:12px!important;border:none!important;margin:0 2px 0!important;vertical-align:middle!important;display:inline-block!important;box-shadow:none!important;"/>
#            <span style="font:inherit!important;color:#888!important;vertical-align:middle!important;display:inline-block!important;box-shadow:none!important;">
#             A Flourish data visualisation
#            </span>
#           </a>
#          </div>
#          <iframe frameborder="0" scrolling="no" src="https://public.flourish.studio/story/39464/embed?auto=1" style="width: 100%; height: 743px;">
#          </iframe>
#          <div class="flourish-credit" style="width:100%!important;margin:0 0 4px!important;text-align:right!important;font-family:Helvetica,sans-serif!important;color:#888!important;font-size:11px!important;font-weight:bold!important;font-style:normal!important;-webkit-font-smoothing:antialiased!important;box-shadow:none!important;">
#           <a href="https://public.flourish.studio/story/39464/?utm_source=showcase&amp;utm_campaign=story/39464" style="display:inline-block!important;text-decoration:none!important;font:inherit!important;color:inherit!important;border:none!important;margin:0 5px!important;box-shadow:none!important;" target="_top">
#            <img alt="Flourish logo" src="https://public.flourish.rocks/resources/bosh.svg" style="font:inherit!important;width:auto!important;height:12px!important;border:none!important;margin:0 2px 0!important;vertical-align:middle!important;display:inline-block!important;box-shadow:none!important;"/>
#            <span style="font:inherit!important;color:#888!important;vertical-align:middle!important;display:inline-block!important;box-shadow:none!important;">
#             A Flourish data visualisation
#            </span>
#           </a>
#          </div>
#         </div>
#         <script src="https://public.flourish.studio/resources/embed.js">
#         </script>
#        </div>
#       </div>
#      </div>
#      <!----------- FINAL CONTENIDO DE LA NOTA ------------>
#      <!----------- LATERAL PUBLICIDADES ------------>
#      <div class="col-lg-3 col-xs-12">
#       <div class="row">
#        <div class="col-lg-7 col-xs-12 padd-bot-10 hidden-xs">
#         <div class="clearfix padd-bot-top-10 hidden" style="width:100%; overflow:hidden;">
#          <div class="fb-like" data-action="like" data-href="https://www.cenital.com/2019/06/15/de-donde-vienen-los-dolares/63771" data-layout="standard" data-share="false" data-show-faces="false">
#          </div>
#         </div>
#         <div class="clearfix hidden">
#          <ul class="list-unstyled">
#           <li class="padd-bot-10">
#            <a class="btn btn-facebook btn-block" href='javascript:window.open("https://www.facebook.com/sharer.php?u=https://www.cenital.com/2019/06/15/de-donde-vienen-los-dolares/63771", "_new", "width=600, height=400, top=100, left=100");' title="">
#             <i class="fa fa-facebook">
#             </i>
#             Compartir
#            </a>
#           </li>
#           <li class="padd-bot-10">
#            <a class="btn btn-twitter btn-block" href='javascript:window.open("https://twitter.com/share?text=&amp;url=https://www.cenital.com/2019/06/15/de-donde-vienen-los-dolares/63771", "_new", "width=600, height=400, top=100, left=100");' title="">
#             <i class="fa fa-twitter">
#             </i>
#             Compartir
#            </a>
#           </li>
#           <li class="padd-bot-10">
#            <a class="btn btn-whatsapp btn-block" data-action="share/whatsapp/share" href="https://api.whatsapp.com/send?text=https://www.cenital.com/2019/06/15/de-donde-vienen-los-dolares/63771" target="_blank">
#             <i class="fa fa-whatsapp">
#             </i>
#             Compartir
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="col-lg-7 col-xs-12 padd-bot-10 visible-xs">
#         <div class="clearfix padd-bot-top-10 hidden" style="width:100%; overflow:hidden;">
#          <div class="fb-like" data-action="like" data-href="https://www.cenital.com/2019/06/15/de-donde-vienen-los-dolares/63771" data-layout="standard" data-share="false" data-show-faces="false">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <!----------- FINAL LATERAL PUBLICIDADES ------------>
#     </div>
#     <!-- FIN ROW -->
#    </div>
#    <!-- FIN CONTAINER -->
#   </section>
#   <!-- FIN SECTION -->
#   <!-- modulo 15 -->
#   <div class="clearfix">
#   </div>
#   <section class="modulo modulo-15b">
#    <div class="container">
#     <div class="row">
#      <div class="col-xs-12">
#       <h2 class="card-title titulo titulo-md bg-h2">
#        <span>
#         Otras notas
#        </span>
#       </h2>
#       <div class="separator-line-blanco hidden">
#       </div>
#      </div>
#      <div class="clearfix">
#      </div>
#      <div class="col-xs-12">
#       <div class="carousel_noticias_flex">
#        <div class="item">
#         <div class="card card-plain card-blog">
#          <div class="card-header card-header-image">
#           <a class="mask-imagen" href="2019/06/15/como-funciona-el-fmi-por-dentro-/63773">
#           </a>
#           <a href="2019/06/15/como-funciona-el-fmi-por-dentro-/63773">
#            <img class="img-responsive" src="contenido/../contenido/noticias/original/1560636112.jpeg"/>
#           </a>
#           <div class="colored-shadow" style="background-image: url('../assets/img/kit/pro/bg5.jpg'); opacity: 1;">
#           </div>
#          </div>
#          <div class="card-body">
#           <h6 class="card-category text-info" style="color: #468C00">
#            Economía
#           </h6>
#           <h2 class="card-title titulo titulo-xxs">
#            <a class="negro" href="2019/06/15/como-funciona-el-fmi-por-dentro-/63773">
#             ¿Cómo funciona el FMI por dentro?
#            </a>
#           </h2>
#          </div>
#         </div>
#        </div>
#        <div class="item">
#         <div class="card card-plain card-blog">
#          <div class="card-header card-header-image">
#           <a class="mask-imagen" href="2019/06/14/que-dicen-los-balances-de-mercado-libre/63766">
#           </a>
#           <a href="2019/06/14/que-dicen-los-balances-de-mercado-libre/63766">
#            <img class="img-responsive" src="contenido/../contenido/noticias/original/1560529477.jpeg"/>
#           </a>
#           <div class="colored-shadow" style="background-image: url('../assets/img/kit/pro/bg5.jpg'); opacity: 1;">
#           </div>
#          </div>
#          <div class="card-body">
#           <h6 class="card-category text-info" style="color: #468C00">
#            Unicornio amarillo
#           </h6>
#           <h2 class="card-title titulo titulo-xxs">
#            <a class="negro" href="2019/06/14/que-dicen-los-balances-de-mercado-libre/63766">
#             Qué dicen los balances de Mercado Libre
#            </a>
#           </h2>
#          </div>
#         </div>
#        </div>
#        <div class="item">
#         <div class="card card-plain card-blog">
#          <div class="card-header card-header-image">
#           <a class="mask-imagen" href="2019/06/14/inflacion-o-inflaciones-/63770">
#           </a>
#           <a href="2019/06/14/inflacion-o-inflaciones-/63770">
#            <img class="img-responsive" src="contenido/../contenido/noticias/original/1560546290.jpeg"/>
#           </a>
#           <div class="colored-shadow" style="background-image: url('../assets/img/kit/pro/bg5.jpg'); opacity: 1;">
#           </div>
#          </div>
#          <div class="card-body">
#           <h6 class="card-category text-info" style="color: #468C00">
#            Economía
#           </h6>
#           <h2 class="card-title titulo titulo-xxs">
#            <a class="negro" href="2019/06/14/inflacion-o-inflaciones-/63770">
#             ¿Inflación o inflaciones?
#            </a>
#           </h2>
#          </div>
#         </div>
#        </div>
#        <div class="item">
#         <div class="card card-plain card-blog">
#          <div class="card-header card-header-image">
#           <a class="mask-imagen" href="2019/06/14/para-pichetto--va-a-haber-mucho-peronismo-detras-del-presidente-macri/63768">
#           </a>
#           <a href="2019/06/14/para-pichetto--va-a-haber-mucho-peronismo-detras-del-presidente-macri/63768">
#            <img class="img-responsive" src="contenido/../contenido/noticias/original/1560542307.jpeg"/>
#           </a>
#           <div class="colored-shadow" style="background-image: url('../assets/img/kit/pro/bg5.jpg'); opacity: 1;">
#           </div>
#          </div>
#          <div class="card-body">
#           <h6 class="card-category text-info" style="color: #468C00">
#            Política
#           </h6>
#           <h2 class="card-title titulo titulo-xxs">
#            <a class="negro" href="2019/06/14/para-pichetto--va-a-haber-mucho-peronismo-detras-del-presidente-macri/63768">
#             Para Pichetto, "va a haber mucho peronismo detrás del presidente Macri"
#            </a>
#           </h2>
#          </div>
#         </div>
#        </div>
#        <div class="item">
#         <div class="card card-plain card-blog">
#          <div class="card-header card-header-image">
#           <a class="mask-imagen" href="2019/06/14/se-viene-otro-superdomingo-electoral/63765">
#           </a>
#           <a href="2019/06/14/se-viene-otro-superdomingo-electoral/63765">
#            <img class="img-responsive" src="contenido/../contenido/noticias/original/1560533537.jpeg"/>
#           </a>
#           <div class="colored-shadow" style="background-image: url('../assets/img/kit/pro/bg5.jpg'); opacity: 1;">
#           </div>
#          </div>
#          <div class="card-body">
#           <h6 class="card-category text-info" style="color: #468C00">
#            Política
#           </h6>
#           <h2 class="card-title titulo titulo-xxs">
#            <a class="negro" href="2019/06/14/se-viene-otro-superdomingo-electoral/63765">
#             Se viene otro superdomingo electoral
#            </a>
#           </h2>
#          </div>
#         </div>
#        </div>
#        <div class="item">
#         <div class="card card-plain card-blog">
#          <div class="card-header card-header-image">
#           <a class="mask-imagen" href="2019/06/14/la-justicia-avalo-la-decision-de-macri-de-no-votar-para-legisladores-del-mercosur/63767">
#           </a>
#           <a href="2019/06/14/la-justicia-avalo-la-decision-de-macri-de-no-votar-para-legisladores-del-mercosur/63767">
#            <img class="img-responsive" src="contenido/../contenido/noticias/original/1560529847.jpeg"/>
#           </a>
#           <div class="colored-shadow" style="background-image: url('../assets/img/kit/pro/bg5.jpg'); opacity: 1;">
#           </div>
#          </div>
#          <div class="card-body">
#           <h6 class="card-category text-info" style="color: #468C00">
#            Elecciones
#           </h6>
#           <h2 class="card-title titulo titulo-xxs">
#            <a class="negro" href="2019/06/14/la-justicia-avalo-la-decision-de-macri-de-no-votar-para-legisladores-del-mercosur/63767">
#             La Justicia avaló la decisión de Macri de no votar para legisladores del Mercosur
#            </a>
#           </h2>
#          </div>
#         </div>
#        </div>
#        <div class="item">
#         <div class="card card-plain card-blog">
#          <div class="card-header card-header-image">
#           <a class="mask-imagen" href="2019/06/14/estados-unidos-refuerza-la-acusacion-contra-iran-con-la-publicacion-de-un-video/63763">
#           </a>
#           <a href="2019/06/14/estados-unidos-refuerza-la-acusacion-contra-iran-con-la-publicacion-de-un-video/63763">
#            <img class="img-responsive" src="contenido/../contenido/noticias/original/1560523525.jpeg"/>
#           </a>
#           <div class="colored-shadow" style="background-image: url('../assets/img/kit/pro/bg5.jpg'); opacity: 1;">
#           </div>
#          </div>
#          <div class="card-body">
#           <h6 class="card-category text-info" style="color: #468C00">
#            Tensión
#           </h6>
#           <h2 class="card-title titulo titulo-xxs">
#            <a class="negro" href="2019/06/14/estados-unidos-refuerza-la-acusacion-contra-iran-con-la-publicacion-de-un-video/63763">
#             Estados Unidos refuerza la acusación contra Irán con la publicación de un video
#            </a>
#           </h2>
#          </div>
#         </div>
#        </div>
#        <div class="item">
#         <div class="card card-plain card-blog">
#          <div class="card-header card-header-image">
#           <a class="mask-imagen" href="2019/06/13/delivery-de-gobernabilidad/63755">
#           </a>
#           <a href="2019/06/13/delivery-de-gobernabilidad/63755">
#            <img class="img-responsive" src="contenido/../contenido/noticias/original/1560433855.jpeg"/>
#           </a>
#           <div class="colored-shadow" style="background-image: url('../assets/img/kit/pro/bg5.jpg'); opacity: 1;">
#           </div>
#          </div>
#          <div class="card-body">
#           <h6 class="card-category text-info" style="color: #468C00">
#            Elecciones
#           </h6>
#           <h2 class="card-title titulo titulo-xxs">
#            <a class="negro" href="2019/06/13/delivery-de-gobernabilidad/63755">
#             Delivery de gobernabilidad
#            </a>
#           </h2>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </section>
#   <section style="background-color:#f2f2f2; margin-top:30px;">
#    <!--
#     <div class="container">
#         <div class="col-xs-12 text-center">
#             <ul class="list-inline social-buttons margin-none padd-bot-top-15">
#                                             <li><a href="https://www.facebook.com/Cenitalcom/" target="_blank"><i class="fa fa-facebook"></i></a></li>
#                                                                                 <li><a href="https://twitter.com/cenitalcom" target="_blank"><i class="fa fa-twitter"></i></a></li>
#                                                                                                                         <li><a href="https://www.instagram.com/cenitalcom/" target="_blank"><img src="img/insta-icon-f.png" style="margin-top: -4px;" /></a></li>
#                                     </ul>
#         </div>
#     </div>
#  -->
#   </section>
#   <section class="bg-footer" style="background-color:#fff;">
#    <div class="container edit padd-bot-top-10">
#     <div class="row-fluid clearfix padding-top padding-bottom">
#      <div class="col-lg-3 col-md-3 col-sm-6 col-xs-12 padd-bot-top-10">
#       <br>
#        <p>
#         <img class="img-responsive" src="img/logo-footer.png"/>
#        </p>
#       </br>
#      </div>
#      <div class="col-lg-9 col-md-9 col-sm-6 col-xs-12 padding-top">
#       <div class="row">
#        <div class="col-md-6 col-xs-6">
#         <h2 class="font-14 bold-700 margin-none padd-bot-top-5">
#          SECCIONES
#         </h2>
#         <hr class="hr-color-foot"/>
#         <ul class="list-unstyled padd-bot-top-10 footer-sub-menu row">
#          <li class="col-sm-6">
#           <a href="politica.html">
#            Política
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="economia.html">
#            Economía
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="judiciales.html">
#            Judiciales
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="tecnologia.html">
#            Tecnología
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="mundo.html">
#            Mundo
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="opinion.html">
#            Opinión
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-md-6 col-xs-6">
#         <h2 class="font-14 bold-700 margin-none padd-bot-top-5">
#          SOBRE CENITAL
#         </h2>
#         <hr class="hr-color-foot"/>
#         <ul class="list-unstyled padd-bot-top-10 footer-sub-menu row">
#          <li class="col-sm-6">
#           <a href="quienes-somos.php">
#            Quiénes Somos
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="contacto.php?t=1">
#            Redacción
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="contacto.php?t=2">
#            Carta al director
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="contacto.php?t=3">
#            Reportar error
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="contacto.php?t=4">
#            Contacto
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- container footer Ends -->
#   </section>
#   <section style="background-color:#282f33;">
#    <div class="container edit padd-bot-top-10">
#     <div class="row-fluid">
#      <div class="col-lg-4 col-md-4 col-sm-6 padd-bot-top-10">
#       <p class="no-margin text-center-xs small blanco">
#        © 2019  | Cenital
#       </p>
#      </div>
#      <div class="col-lg-4 col-md-5 col-sm-6 padd-5">
#       <p class="no-margin text-center-xs blanco hidden">
#        <img src="img/logo-footer-c.png">
#         <img class="hidden" src="img/wa.png">
#          0249 4 42 7493 / 94
#         </img>
#        </img>
#       </p>
#      </div>
#      <div class="col-md-12 col-xs-12 hidden-md hidden-lg">
#       <div class="centrar" style="width:220px;">
#        <a class="cds" href="http://www.creadoresdesitios.com.ar" target="_blank">
#         Desarrollo Web / Creadores de Sitios
#        </a>
#       </div>
#      </div>
#      <div class="col-lg-4 col-md-3 col-sm-3 hidden-sm hidden-xs padd-5">
#       <a class="cds" href="http://www.creadoresdesitios.com.ar" target="_blank">
#        <span class="hidden-md">
#         Desarrollo Web /
#        </span>
#        Creadores de Sitios
#       </a>
#      </div>
#      <div class="col-md-12 col-xs-12 hidden-md hidden-lg text-center">
#       <a href="http://www.lemotsur.com.ar" target="_blank">
#       </a>
#      </div>
#     </div>
#    </div>
#   </section>
#   <!-- The Bootstrap Image Gallery lightbox, should be a child element of the document body -->
#   <div class="blueimp-gallery blueimp-gallery-controls" id="blueimp-gallery">
#    <!-- The container for the modal slides -->
#    <div class="slides">
#    </div>
#    <!-- Controls for the borderless lightbox -->
#    <h3 class="title">
#    </h3>
#    <a class="prev">
#     ‹
#    </a>
#    <a class="next">
#     ›
#    </a>
#    <a class="close">
#     ×
#    </a>
#    <a class="play-pause">
#    </a>
#    <ol class="indicator">
#    </ol>
#    <!-- The modal dialog, which will be used to wrap the lightbox content -->
#    <div class="modal fade">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" type="button">
#         ×
#        </button>
#        <h4 class="modal-title">
#        </h4>
#       </div>
#       <div class="modal-body next">
#       </div>
#       <div class="modal-footer">
#        <button class="btn btn-default pull-left prev" type="button">
#         <i class="glyphicon glyphicon-chevron-left">
#         </i>
#         Previous
#        </button>
#        <button class="btn btn-primary next" type="button">
#         Next
#         <i class="glyphicon glyphicon-chevron-right">
#         </i>
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- JS GENERAL -->
#   <script src="js/jquery.min.js">
#   </script>
#   <script src="js/bootstrap.js">
#   </script>
#   <!-- MARQUESINA -->
#   <script src="js/jquery.smarticker.min.js" type="text/javascript">
#   </script>
#   <script>
#    $('.smarticker1').smarticker({
#     controllerType: 1,
#     title: 'ÚLTIMAS NOTICIAS',
#     animation: 'slide',
#     speed: 1000,
#     progressbar: false
#     });
#   </script>
#   <script src="js/common.js?v=1.9">
#   </script>
#   <!-- GALERIA -->
#   <script src="js/jquery.blueimp-gallery.min.js">
#   </script>
#   <script src="js/bootstrap-image-gallery.js">
#   </script>
#   <script language="JavaScript">
#    /*------------ JS BUSQUEDA --------------------*/
#         /*$(".buy-search").hide();*/
#         $(".boton-nota-despliega").click(function(){
#             $(".nota-despliega").stop();
#             if ($(".nota-despliega").hasClass("on")){
#                 $(".nota-despliega").slideUp();
#                 $(".nota-despliega").removeClass("on");
#             } else {
#                 $(".nota-despliega").slideDown();
#                 $(".nota-despliega").addClass("on");
#             }
#         });
#     /*------------ FIN JS BUSQUEDA --------------------*/
#
# (function($) {
#   $(document).ready(function(){
#     $(".cerrar-nota").on("click", function(){
#       $(this).toggleClass("check").toggleClass("uncheck");
#     });
#   });
# })(jQuery);
#   </script>
#   <!-- OWL CAROUSEL -->
#   <script src="js/owl-carousel/owl.carousel.min.js">
#   </script>
#   <script src="js/owl-carousel/owl_slider.js">
#   </script>
#   <script language="JavaScript">
#    /*------------ JS BUSQUEDA --------------------*/
# 	/*$(".buy-search").hide();*/
# 	$(".boton-menu-top").click(function(){
# 		$(".buy-search").stop();
# 		if ($(this).hasClass("on")){
# 			$(".buy-search").slideUp();
# 			$(this).removeClass("on");
# 		} else {
# 			$(".buy-search").slideDown();
# 			$(this).addClass("on");
# 		}
# 	});
# /*------------ FIN JS BUSQUEDA --------------------*/
#   </script>
#  </body>
# </html>
