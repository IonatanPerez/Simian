# %%
import requests
from bs4 import BeautifulSoup
import time
import datetime
import json
import os

class Cenital:
    
    myname = "Cenital"
    savefolder = "./dataCenital/"
    rawdata = "raw/"
    
    class Home:
    
        url = "https://www.cenital.com/"
        
        def buscarnotas():
            
            cenital = Cenital()
            cenital.gethome()
            listadenotas = cenital.home.getlistofnotes()
            Cenital.saveinfo(listadenotas)
            Cenital.removemetadata(listadenotas)
            return listadenotas

        def __init__ (self):
            self.page = requests.get(self.url)
            if self.page.status_code != 200:
                print (self.page.status_code)
            else:
                print ("Home de " + Cenital.myname + " descargado con exito.")
            self.bpage = BeautifulSoup(self.page.content, 'html.parser')

        def printpretty(self):
            print(self.bpage.prettify())
            
        def getlistofnotes(self):
            info = Cenital.generateinfo("-notasHome")
            # Buscamos con el class card-title todas las notas porque es lo unico que idententifica a todas las notas del home
            titulos = self.bpage.find_all(attrs={"class":"card-title"})
            for titulo in titulos:
                vinculo = titulo.find_all("a")
                assert len (vinculo) == 1, "error, se encontro mas de un titulo por nota"
                info [vinculo[0]['href']] = {}
                info [vinculo[0]['href']]["Url"] = Cenital.Home.url + vinculo[0]['href']
                info [vinculo[0]['href']]["Titulo"] = vinculo[0].string
            return info
            
    class Noticia:
        
        def __init__ (self,url):
            self.url = url
            self.id = self.url.split("/")[-1]
            print (self.id)
            self.page = requests.get(self.url)
            if self.page.status_code != 200:
                print (self.page.status_code)
            else:
                print ("Nota " + self.url + " descargada con exito.")
            self.bpage = BeautifulSoup(self.page.content, 'html.parser')

        def printpretty(self):
            print(self.bpage.prettify())
        
        def generarinfo(self):
            self.info = Cenital.generateinfo("notaid-"+self.id,fecha=False)
            self.datosprevios = False
            # Aca hay que recopilar la info como si no hubiera datos previos y despues comparar en caso de que haya
            
            self.buscardatosprevios()
            Cenital.saveinfo(self.info)
            
        def buscardatosprevios(self):
            if os.path.exists(self.info["metadata"]["filename"]):
                self.datosprevios = True
                with open(self.info["metadata"]["filename"]) as file:  
                    self.infoprevia = json.load(file)
                
                
    def gethome(self):
        self.home = self.Home()
        
    def generateinfo (name,fecha=True):
        info = {}
        info["metadata"] = {}
        info["metadata"]["timestampofsearch"] = datetime.datetime.now().timestamp()
        info["metadata"]["timeofsearch"] = datetime.datetime.fromtimestamp(info["metadata"]["timestampofsearch"]).isoformat()
        if fecha:
            info["metadata"]["filename"] = Cenital.savefolder + Cenital.rawdata + datetime.datetime.fromtimestamp(info["metadata"]["timestampofsearch"]).strftime("%Y-%m-%d-%H-%M") + name + ".json"
        else:
            info["metadata"]["filename"] = Cenital.savefolder + Cenital.rawdata + name + ".json"
        return info
        
    def removemetadata(info):
        del info["metadata"]
        
    def saveinfo(info):
        with open(info["metadata"]["filename"], 'w') as f:
            json.dump(info, f)
            
    
        
        
    # Inicializa las carpetas si no existen
    if not os.path.exists(savefolder):
        os.makedirs(savefolder)
    if not os.path.exists(savefolder+rawdata):
        os.makedirs(savefolder+rawdata)

# %%
cenital = Cenital()
cenital.gethome()
listadenotas = cenital.home.getlistofnotes()
Cenital.removemetadata(listadenotas)
pichetto al Consejo de la Magistratura'}, '2019/06/19/que-va-a-pasar-con-el-bloque-del-pj-en-el-senado-/63787': {'Url': 'https://www.cenital.com/2019/06/19/que-va-a-pasar-con-el-bloque-del-pj-en-el-senado-/63787', 'Titulo': '¿Qué va a pasar con el bloque del PJ en el Senado?'}, '2019/06/14/inflacion-de-ricos--inflacion-de-pobres/63770': {'Url': 'https://www.cenital.com/2019/06/14/inflacion-de-ricos--inflacion-de-pobres/63770', 'Titulo': 'Inflación de ricos, inflación de pobres'}, '2019/06/14/que-dicen-los-balances-de-mercado-libre/63766': {'Url': 'https://www.cenital.com/2019/06/14/que-dicen-los-balances-de-mercado-libre/63766', 'Titulo': 'Qué dicen los balances de Mercado Libre'}, '2019/06/16/pauta-fantasma-los-casos-se-multiplican-en-todo-el-pais-y-ya-hay-mas-de-$100-millones-bajo-sospecha/63774': {'Url': 'https://www.cenital.com/2019/06/16/pauta-fantasma-los-casos-se-multiplican-en-todo-el-pais-y-ya-hay-mas-de-$100-millones-bajo-sospecha/63774', 'Titulo': ' Pauta fantasma: los casos se multiplican en todo el país y ya hay más de $100 millones bajo sospecha'}, '2019/06/16/la-soga-que-une-dolores-con-comodoro-py/63776': {'Url': 'https://www.cenital.com/2019/06/16/la-soga-que-une-dolores-con-comodoro-py/63776', 'Titulo': ' La soga que une Dolores con Comodoro Py'}, '2019/06/15/focus-hablemos-de-las-proximas-elecciones/63772': {'Url': 'htt ...

# %%
noticia.printpretty()
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <base href="https://www.cenital.com/"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
#   <meta content="Cenital" name="author"/>
#   <link href="favicon.ico" rel="icon" type="image/png"/>
#   <title>
#    La soga que une Dolores con Comodoro Py
#   </title>
#   <meta content="Tensión entre Ramos Padilla y Bonadio. D'alessio y Cuadernos, en qué anda cada causa.
#
# " name="description"/>
#   <link href="https://www.cenital.com/2019/06/16/la-soga-que-une-dolores-con-comodoro-py/63776" rel="canonical">
#    <meta content="https://www.cenital.com/2019/06/16/la-soga-que-une-dolores-con-comodoro-py/63776" property="og:url">
#     <meta content="article" property="og:type">
#      <meta content="La soga que une Dolores con Comodoro Py" property="og:title">
#       <meta content="Tensión entre Ramos Padilla y Bonadio. D'alessio y Cuadernos, en qué anda cada causa.
#
# " property="og:description">
#        <meta content="https://www.cenital.com/contenido/noticias/original/1560713036.jpeg" property="og:image">
#         <meta content="summary_large_image" name="twitter:card"/>
#         <meta content="@cenitalcom" name="twitter:site"/>
#         <meta content="@cenitalcom" name="twitter:creator"/>
#         <meta content="La soga que une Dolores con Comodoro Py" name="twitter:title"/>
#         <meta content="Tensión entre Ramos Padilla y Bonadio. D'alessio y Cuadernos, en qué anda cada causa.
#
# " name="twitter:description"/>
#         <meta content="https://www.cenital.com/contenido/noticias/original/1560713036.jpeg" name="twitter:image"/>
#         <!-- CCS GENERAL -->
#         <link href="css/bootstrap.min.css" rel="stylesheet"/>
#         <link href="css/custom-2.css?v=1.61" rel="stylesheet"/>
#         <link href="css/basic-styles.css?v=1.61" rel="stylesheet"/>
#         <link href="css/personal-styles.css?v=1.61" rel="stylesheet"/>
#         <link href="css/casas-de-hoy.css?v=1.61" rel="stylesheet"/>
#         <link href="css/card.css?v=1.61" rel="stylesheet"/>
#         <link href="css/modulos.css?v=1.61" rel="stylesheet"/>
#         <link href="css/polsk-styles.css?v=1.61" rel="stylesheet"/>
#         <!-- CCS FUENTES -->
#         <link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700" rel="stylesheet"/>
#         <link href="https://fonts.googleapis.com/css?family=Noticia+Text&amp;display=swap" rel="stylesheet"/>
#         <link href="font-awesome-4.4.0/css/font-awesome.min.css" rel="stylesheet" type="text/css">
#          <!-- OWL CAROUSEL -->
#          <link href="js/owl-carousel/owl.carousel.css?v=1.61" rel="stylesheet"/>
#          <link href="js/owl-carousel/owl.theme.default.min.css" rel="stylesheet"/>
#          <!-- OTHER CAROUSEL -->
#          <link href="css/personal-carousel.css?v=1.61" rel="stylesheet"/>
#          <!-- MARQUESINA -->
#          <link href="css/jquery.smarticker.min.css" rel="stylesheet">
#           <link href="css/marquesina.css?v=1.61" rel="stylesheet">
#            <!-- NEWS BOX -->
#            <link href="css/site.css?v=1.61" rel="stylesheet" type="text/css">
#             <!-- BUSCADOR MENU
# <link href="css/search-styles.css?v=1.61" rel="stylesheet" type="text/css" />-->
#             <!-- BUSCADOR GALERIA -->
#             <link href="css/blueimp-gallery.min.css" rel="stylesheet"/>
#             <link href="css/bootstrap-image-gallery.css?v=1.61" rel="stylesheet"/>
#             <link href="css/sonar.css?v=1.61" rel="stylesheet"/>
#             <link href="manifest.json?v=1.61" rel="manifest"/>
#             <!-- Global site tag (gtag.js) - Google Analytics -->
#             <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-33282694-18">
#             </script>
#             <script>
#              window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-33282694-18');
#             </script>
#             <style>
#              .detalle-noticia p{
#     /*margin-bottom:0px;*/
# }
#
# .contexto{
# 	padding: 20px;
# 	background-color:#f4f4f4;
# 	margin-bottom: 40px;
# }
#
# .contexto h2 {
#     font-size: 16px;
#     font-weight: 600;
# 	margin-bottom:15px;
# }
#
# .contexto h2 a {
#     color: #ff312e;
# 	cursor:pointer;
# }
#
# .contexto p {
#     font-size: 13.4px;
# 	line-height:20px;
# 	color: #666;
# }
#
# .cerrar-nota{
#     display: inline-block;
#     /* margin-bottom: -100px; */
#     position: absolute;
# 	cursor:pointer;
# 	/*margin-top:15px;*/
# 	height:44px;
# 	width:44px;
# 	background-image:url(img/cerrar-nota-mas.png);
# 	background-position:center;
# 	-webkit-transition: 0.5s;
# 	-moz-transition: 0.5s;
# 	-ms-transition: 0.5s;
# 	transition: 0.5s;
# }
#
# .cerrar-nota.uncheck {
# 	background-image:url(img/cerrar-nota.png);
# 	-webkit-transition: 0.5s;
# 	-moz-transition: 0.5s;
# 	-ms-transition: 0.5s;
# 	transition: 0.5s;
# }
#
# .cerrar-nota.check {
# 	background-image:url(img/cerrar-nota.png);
# 	-webkit-transition: 0.5s;
# 	-moz-transition: 0.5s;
# 	-ms-transition: 0.5s;
# 	transition: 0.5s;
# }
#
#
#
# .titulo-new{
#     background-color: white;
#     padding-top: 30px;
#     padding-right: 40px;
#     padding-bottom: 15px;
#     margin-top: -45px;
#     width: 76%;
#     border-radius: 0px 7px;
# }
#
# @media (max-width: 992px) {
# .titulo-new{
#     background-color: white;
#     padding-top: 10px;
#     padding-right: 0px;
#     padding-bottom: 10px;
#     margin-top: 0px;
#     width: auto;
#     border-radius: 0px 0px;
# 	font-size:22px !important;
# }
# }
#
# .link-autor{
#     font-size: 14px; font-weight: bold;
# }
#
# .periodista-email, .periodista-redes{
#     font-weight: normal;
# }
# .detalle-noticia p, .detalle-noticia div{
#     line-height: 150%;
# }
#             </style>
#             <style>
#              .carousel_noticias_flex .owl-stage {
# 	    display: flex;
# 	}
# 	.carousel_noticias_flex	.owl-item {
# 		display: flex;
# 		flex: 1 0 auto;
# 	}
# 	.carousel_noticias_flex	.owl-item .item {
# 	    display: flex;
# 	}
#             </style>
#            </link>
#           </link>
#          </link>
#         </link>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </link>
#  </head>
#  <body class="auto-padd">
#   <input name="pagina_publicidades" type="hidden" value="Amplia-Noticia"/>
#   <div id="fb-root">
#   </div>
#   <script>
#    (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/es_LA/sdk.js#xfbml=1&version=v2.6";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#   </script>
#   <section class="">
#    <input name="pagina_publicidades" type="hidden" value="Amplia-Noticia"/>
#    <div class="navbar navbar-default navbar-fixed-top normal yamm" role="navigation">
#     <div class="container">
#      <div class="navbar-header">
#       <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#        <span class="sr-only">
#         navegación
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#       <p class="visible-xs pull-right boton-carrito">
#        <a class="hidden-sm hidden-lg hidden-md negro boton-menu-top">
#         <img src="img/search-xs.png"/>
#        </a>
#       </p>
#       <a class="navbar-brand" href="index.html">
#        <img src="img/logo.png"/>
#       </a>
#      </div>
#      <div class="navbar-collapse collapse">
#       <ul class="nav navbar-nav navbar-left-paul">
#        <li class="dropdown">
#         <a class="dropdown-toggle" data-toggle="dropdown" href="#" id="dLabel">
#          Argentina
#          <span class="caret">
#          </span>
#         </a>
#         <ul class="dropdown-menu">
#          <li>
#           <a href="politica.html">
#            Política
#           </a>
#          </li>
#          <li>
#           <a href="economia.html">
#            Economía
#           </a>
#          </li>
#          <li>
#           <a href="judiciales.html">
#            Judiciales
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="mundo.html">
#          Mundo
#         </a>
#        </li>
#        <li>
#         <a href="opinion.html">
#          Opinión
#         </a>
#        </li>
#        <li class="dropdown">
#         <a class="dropdown-toggle" data-toggle="dropdown" href="#" id="dLabel">
#          Más
#          <span class="caret">
#          </span>
#         </a>
#         <ul class="dropdown-menu">
#          <li>
#           <a href="tecnologia.html">
#            Tecnología
#           </a>
#          </li>
#          <li>
#           <a href="newsletter.php">
#            Newsletters
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="hidden-xs hidden-md hidden-lg">
#         <a class="boton-menu-top" style="cursor:pointer;">
#          <img src="img/search-xs.png"/>
#         </a>
#        </li>
#       </ul>
#       <span class="redes-head list-inline navbar-right hidden-xs hidden-sm">
#        <a class="social" href="https://www.facebook.com/Cenitalcom/" target="_blank">
#         <i class="fa fa-facebook">
#         </i>
#        </a>
#        <a class="social" href="https://twitter.com/cenitalcom" target="_blank">
#         <i class="fa fa-twitter">
#         </i>
#        </a>
#        <a class="social" href="https://www.instagram.com/cenitalcom/" target="_blank">
#         <img src="img/insta-icon.png" style="    margin-top: -4px;"/>
#        </a>
#        <a class="negro boton-menu-top" style="display: inline-block;margin: 2px;margin-left: 5px; cursor:pointer;">
#         <img src="img/search-xs.png"/>
#        </a>
#       </span>
#      </div>
#      <!--/.nav-collapse -->
#     </div>
#     <!--/.container-fluid -->
#     <div class="buy-search" style="display:none;background-color: #f9f9f9;">
#      <section class="padd-bot-top-10 bg-buscador">
#       <div class="container edit">
#        <div class="row">
#         <div class="col-lg-offset-2- col-lg-8- col-md-8- col-sm-6- col-xs-12">
#          <form action="resultados.php" method="get" name="buscar">
#           <div class="input-group">
#            <input class="form-control input-lg radius-none" name="q" placeholder="Buscar noticias dentro del sitio" style="font-size: small;
#     font-weight: 300;" type="text">
#             <div class="input-group-btn">
#              <button class="btn btn-default input-lg radius-none" type="submit">
#               <img src="img/lupita.png" width="17"/>
#              </button>
#             </div>
#            </input>
#           </div>
#          </form>
#         </div>
#        </div>
#        <!-- FIN ROW -->
#       </div>
#       <!-- FIN CONTAINER -->
#      </section>
#      <!-- FIN SECTION -->
#     </div>
#    </div>
#   </section>
#   <section class="padd-bot-top-20">
#    <div class="container">
#     <div class="row padding-top padding-bottom">
#      <div class="col-lg-10 col-md-10 col-sm-12 col-xs-12 amplia-nota-info">
#       <ul class="nav nav-tabs hidden" id="myTab" style="margin-bottom: 0px; border: 0px; position: absolute; top: 3px; left: 33px; background-color: transparent; z-index: 100;">
#        <li class="active">
#         <a aria-expanded="true" data-toggle="tab" href="#foto">
#          <i class="fa fa-camera-retro fa-lg">
#          </i>
#          FOTOS
#         </a>
#        </li>
#       </ul>
#       <div class="tab-content" id="myTabContent">
#        <div class="tab-pane fade active in" id="foto">
#         <div class="carousel slide transition-timer-carousel" data-ride="carousel" id="transition-timer-carousel">
#          <!-- Wrapper for slides -->
#          <div class="carousel-inner">
#           <div class="item active">
#            <img class="img-responsive" src="contenido/../contenido/noticias/original/1560713036.jpeg"/>
#           </div>
#          </div>
#          <!-- Controls -->
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="col-lg-2 col-md-2 col-sm-12 col-xs-12 hidden-sm hidden-xs" style="padding-top:8px;">
#       <p class="small gris">
#       </p>
#      </div>
#      <div class="col-lg-2 col-md-2 col-sm-12 col-xs-12 visible-sm visible-xs amplia-nota-info" style="padding-top:6px;">
#       <p class="small gris">
#       </p>
#      </div>
#      <div class="col-lg-10 col-md-10 col-sm-12 col-xs-12 amplia-nota-info">
#       <h2 class="card-title titulo titulo-lg titulo-new">
#        La soga que une Dolores con Comodoro Py
#       </h2>
#       <p class="fecha-interior hidden">
#        16/06/2019 16:15:00
#       </p>
#      </div>
#      <div class="col-lg-8 col-md-8 col-sm-12 col-xs-12 amplia-nota-info">
#       <p class="texto3" style="font-family: 'Noticia Text', serif; font-size: 20px; color: #555; line-height: 150%; ">
#        Tensión entre Ramos Padilla y Bonadio. D'alessio y Cuadernos, en qué anda cada causa.
#       </p>
#      </div>
#     </div>
#     <div class="row">
#      <!----------- CONTENIDO DE LA NOTA ------------>
#      <div class="col-lg-9 col-xs-12 amplia-nota-info">
#       <div class="row">
#        <div class="col-xs-12 padd-bot-10">
#         <p class="persona-nota">
#          <img class="img-circle pull-left" src="contenido/../contenido/periodistas/1559756868.jpg" style="margin-top: 7px;" width="44"/>
#          <span class="box-span">
#           <i>
#            <a class="link-autor negro" href="periodista-ariel-zak-47">
#             Ariel Zak
#            </a>
#           </i>
#           <br/>
#           <span class="periodista-redes negro">
#            16 de junio de 2019 16:15 hs
#           </span>
#           <br/>
#           <span class="periodista-email">
#            ariel@cenital.com
#           </span>
#           <br class="visible-xs"/>
#           <i class="fa fa-twitter">
#           </i>
#           <a class="negro periodista-redes" href="https://twitter.com/Ariel_Zak" target="_blank">
#            @Ariel_Zak
#           </a>
#          </span>
#          <a class="mas-notas hidden" href="periodista-ariel-zak-47">
#           Ver más notas del periodista
#          </a>
#         </p>
#         <div class="share-buttons hidden-xs">
#          <!--<h5>Compartir</h5>-->
#          <div class="posts-shares">
#           <div class="social-shares clearfix">
#            <ul>
#             <li>
#              <a class="btn-facebook" href='javascript:window.open("https://www.facebook.com/sharer.php?u=https://www.cenital.com/2019/06/16/la-soga-que-une-dolores-con-comodoro-py/63776", "_new", "width=600, height=400, top=100, left=100");' title="">
#               <i class="fa fa-facebook">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a class="btn-twitter" href='javascript:window.open("https://twitter.com/share?text=La soga que une dolores con comodoro py&amp;url=https://www.cenital.com/2019/06/16/la-soga-que-une-dolores-con-comodoro-py/63776&amp;via=cenitalcom", "_new", "width=600, height=400, top=100, left=100");' title="">
#               <i class="fa fa-twitter">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a class="btn-whatsapp" data-action="share/whatsapp/share" href="https://api.whatsapp.com/send?text=https://www.cenital.com/2019/06/16/la-soga-que-une-dolores-con-comodoro-py/63776" target="_blank">
#               <i class="fa fa-whatsapp">
#               </i>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#         <!-- fin share -->
#        </div>
#        <div class="col-xs-12 visible-xs">
#         <ul class="list-unstyled list-inline text-center">
#          <li class="padd-bot-10">
#           <a class="btn btn-sm btn-facebook btn-block" href='javascript:window.open("https://www.facebook.com/sharer.php?u=https://www.cenital.com/2019/06/16/la-soga-que-une-dolores-con-comodoro-py/63776", "_new", "width=600, height=400, top=100, left=100");' title="">
#            <i class="fa fa-facebook">
#            </i>
#           </a>
#          </li>
#          <li class="padd-bot-10">
#           <a class="btn btn-sm btn-twitter btn-block" href='javascript:window.open("https://twitter.com/share?text=&amp;url=https://www.cenital.com/2019/06/16/la-soga-que-une-dolores-con-comodoro-py/63776", "_new", "width=600, height=400, top=100, left=100");' title="">
#            <i class="fa fa-twitter">
#            </i>
#           </a>
#          </li>
#          <li class="padd-bot-10">
#           <a class="btn btn-whatsapp btn-block btn-sm" data-action="share/whatsapp/share" href="https://api.whatsapp.com/send?text=https://www.cenital.com/2019/06/16/la-soga-que-une-dolores-con-comodoro-py/63776" target="_blank">
#            <i class="fa fa-whatsapp">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-xs-12 padd-bot-20">
#        </div>
#        <div class="col-xs-12 padd-bot-10 detalle-noticia">
#         <p>
#          La soga (invisible) mide 202 kilómetros. Y se tensa cada vez que alguien tira de uno de sus extremos. La sujeta de una punta el juez federal de Dolores Alejo Ramos Padilla y de la otra su colega porteño Claudio Bonadio. Cada uno tiene en sus manos una investigación en la que el otro se encuentra, cuanto menos, cuestionado. Esto recién empieza.
#          <br/>
#         </p>
#         <p>
#          Esta semana quien tiró con más fuerza de la cuerda fue Ramos Padilla. El martes emitió una resolución en la que dejó por escrito, entre otras cosas, que Bonadio está querellado en la causa en la que se investiga una supuesta asociación ilícita dedicada a la extorsión y el espionaje ilegal. Es la causa por la que está detenido el falso abogado Marcelo D'alessio.
#         </p>
#         <p>
#          El juez de Dolores le recordó a su colega que cuenta con los mismos derechos que asisten a los imputados y que puede presentarse cuando quiera en el tribunal a "prestar declaración, aclarar los hechos  y/o indicar las pruebas que a su juicio podrían resultar útiles y conducentes".
#         </p>
#         <p>
#          Esa causa se inició por la denuncia presentada por el empresario Pedro Etchebest el 28 de enero último cuando sostuvo que Marcelo D'alessio lo había extorsionado y le había reclamado dinero para hacerlo zafar de quedar pegado en la causa de los cuadernos. Esa plata, le decía, era para arreglar al fiscal Carlos Stornelli, que por estos días se encuentra en rebeldía por negarse a declarar en el expediente.
#         </p>
#         <p>
#          Ramos Padilla le mandó el mismo mensaje que a Bonadio a las diputadas nacionales Elisa Carrió y Paula Oliveto y a la legisladora del Parlasur Mariana Zuvic. Las tres aparecen mencionadas en la causa que tramita en Dolores. Oliveto, incluso, reconoció públicamente que alguna vez trató con D'alessio. Resta saber si trabajó con ellas, para ellas o simplemente alardeaba un vínculo que no tenía.
#          Una tercera denuncia podría aumentar la tensión. El detenido ex secretario de Transporte, Schiavi, pidió que se investigue cómo un texto aparentemente producido por servicios de inteligencia -los informes con las transcripciones de las escuchas- llegó a manos de Carrió. Esa denuncia, por conexidad, también la tiene Bonadio, con la fiscal Mangano. La representante del ministerio público fiscal solicitó, entre otras medidas, que se secuestren las grabaciones de las cámaras de seguridad que permitan ver el frente de las oficinas donde Carrió dijo haber recibido el sobre anónimo. ¿Quedará algún registro? ¿Será cierto que llegaron como Carrió dijo o fue una simple forma de evitar decir de dónde las había sacado? Si se descubriera quién filtró las transcripciones de las escuchas utilizadas en febrero para intentar dinamitar el caso D'alessio o quién filtró las escuchas de esas transcripciones, la soga podría tensarse más. Incluso romperse.
#         </p>
#        </div>
#       </div>
#      </div>
#      <!----------- FINAL CONTENIDO DE LA NOTA ------------>
#      <!----------- LATERAL PUBLICIDADES ------------>
#      <div class="col-lg-3 col-xs-12">
#       <div class="row">
#        <div class="col-lg-7 col-xs-12 padd-bot-10 hidden-xs">
#         <div class="clearfix padd-bot-top-10 hidden" style="width:100%; overflow:hidden;">
#          <div class="fb-like" data-action="like" data-href="https://www.cenital.com/2019/06/16/la-soga-que-une-dolores-con-comodoro-py/63776" data-layout="standard" data-share="false" data-show-faces="false">
#          </div>
#         </div>
#         <div class="clearfix hidden">
#          <ul class="list-unstyled">
#           <li class="padd-bot-10">
#            <a class="btn btn-facebook btn-block" href='javascript:window.open("https://www.facebook.com/sharer.php?u=https://www.cenital.com/2019/06/16/la-soga-que-une-dolores-con-comodoro-py/63776", "_new", "width=600, height=400, top=100, left=100");' title="">
#             <i class="fa fa-facebook">
#             </i>
#             Compartir
#            </a>
#           </li>
#           <li class="padd-bot-10">
#            <a class="btn btn-twitter btn-block" href='javascript:window.open("https://twitter.com/share?text=&amp;url=https://www.cenital.com/2019/06/16/la-soga-que-une-dolores-con-comodoro-py/63776", "_new", "width=600, height=400, top=100, left=100");' title="">
#             <i class="fa fa-twitter">
#             </i>
#             Compartir
#            </a>
#           </li>
#           <li class="padd-bot-10">
#            <a class="btn btn-whatsapp btn-block" data-action="share/whatsapp/share" href="https://api.whatsapp.com/send?text=https://www.cenital.com/2019/06/16/la-soga-que-une-dolores-con-comodoro-py/63776" target="_blank">
#             <i class="fa fa-whatsapp">
#             </i>
#             Compartir
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="col-lg-7 col-xs-12 padd-bot-10 visible-xs">
#         <div class="clearfix padd-bot-top-10 hidden" style="width:100%; overflow:hidden;">
#          <div class="fb-like" data-action="like" data-href="https://www.cenital.com/2019/06/16/la-soga-que-une-dolores-con-comodoro-py/63776" data-layout="standard" data-share="false" data-show-faces="false">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <!----------- FINAL LATERAL PUBLICIDADES ------------>
#     </div>
#     <!-- FIN ROW -->
#    </div>
#    <!-- FIN CONTAINER -->
#   </section>
#   <!-- FIN SECTION -->
#   <!-- modulo 15 -->
#   <div class="clearfix">
#   </div>
#   <section class="modulo modulo-15b">
#    <div class="container">
#     <div class="row">
#      <div class="col-xs-12">
#       <h2 class="card-title titulo titulo-md bg-h2">
#        <span>
#         Otras notas
#        </span>
#       </h2>
#       <div class="separator-line-blanco hidden">
#       </div>
#      </div>
#      <div class="clearfix">
#      </div>
#      <div class="col-xs-12">
#       <div class="carousel_noticias_flex">
#        <div class="item">
#         <div class="card card-plain card-blog">
#          <div class="card-header card-header-image">
#           <a class="mask-imagen" href="2019/06/16/pauta-fantasma-los-casos-se-multiplican-en-todo-el-pais-y-ya-hay-mas-de-$100-millones-bajo-sospecha/63774">
#           </a>
#           <a href="2019/06/16/pauta-fantasma-los-casos-se-multiplican-en-todo-el-pais-y-ya-hay-mas-de-$100-millones-bajo-sospecha/63774">
#            <img class="img-responsive" src="contenido/../contenido/noticias/original/1

#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </section>
#   <section style="background-color:#f2f2f2; margin-top:30px;">
#    <!--
#     <div class="container">
#         <div class="col-xs-12 text-center">
#             <ul class="list-inline social-buttons margin-none padd-bot-top-15">
#                                             <li><a href="https://www.facebook.com/Cenitalcom/" target="_blank"><i class="fa fa-facebook"></i></a></li>
#                                                                                 <li><a href="https://twitter.com/cenitalcom" target="_blank"><i class="fa fa-twitter"></i></a></li>
#                                                                                                                         <li><a href="https://www.instagram.com/cenitalcom/" target="_blank"><img src="img/insta-icon-f.png" style="margin-top: -4px;" /></a></li>
#                                     </ul>
#         </div>
#     </div>
#  -->
#   </section>
#   <section class="bg-footer" style="background-color:#fff;">
#    <div class="container edit padd-bot-top-10">
#     <div class="row-fluid clearfix padding-top padding-bottom">
#      <div class="col-lg-3 col-md-3 col-sm-6 col-xs-12 padd-bot-top-10">
#       <br>
#        <p>
#         <img class="img-responsive" src="img/logo-footer.png"/>
#        </p>
#       </br>
#      </div>
#      <div class="col-lg-9 col-md-9 col-sm-6 col-xs-12 padding-top">
#       <div class="row">
#        <div class="col-md-6 col-xs-6">
#         <h2 class="font-14 bold-700 margin-none padd-bot-top-5">
#          SECCIONES
#         </h2>
#         <hr class="hr-color-foot"/>
#         <ul class="list-unstyled padd-bot-top-10 footer-sub-menu row">
#          <li class="col-sm-6">
#           <a href="politica.html">
#            Política
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="economia.html">
#            Economía
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="judiciales.html">
#            Judiciales
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="tecnologia.html">
#            Tecnología
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="mundo.html">
#            Mundo
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="opinion.html">
#            Opinión
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-md-6 col-xs-6">
#         <h2 class="font-14 bold-700 margin-none padd-bot-top-5">
#          SOBRE CENITAL
#         </h2>
#         <hr class="hr-color-foot"/>
#         <ul class="list-unstyled padd-bot-top-10 footer-sub-menu row">
#          <li class="col-sm-6">
#           <a href="quienes-somos.php">
#            Quiénes Somos
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="contacto.php?t=1">
#            Redacción
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="contacto.php?t=2">
#            Carta al director
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="contacto.php?t=3">
#            Reportar error
#           </a>
#          </li>
#          <li class="col-sm-6">
#           <a href="contacto.php?t=4">
#            Contacto
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- container footer Ends -->
#   </section>
#   <section style="background-color:#282f33;">
#    <div class="container edit padd-bot-top-10">
#     <div class="row-fluid">
#      <div class="col-lg-4 col-md-4 col-sm-6 padd-bot-top-10">
#       <p class="no-margin text-center-xs small blanco">
#        © 2019  | Cenital
#       </p>
#      </div>
#      <div class="col-lg-4 col-md-5 col-sm-6 padd-5">
#       <p class="no-margin text-center-xs blanco hidden">
#        <img src="img/logo-footer-c.png">
#         <img class="hidden" src="img/wa.png">
#          0249 4 42 7493 / 94
#         </img>
#        </img>
#       </p>
#      </div>
#      <div class="col-md-12 col-xs-12 hidden-md hidden-lg">
#       <div class="centrar" style="width:220px;">
#        <a class="cds" href="http://www.creadoresdesitios.com.ar" target="_blank">
#         Desarrollo Web / Creadores de Sitios
#        </a>
#       </div>
#      </div>
#      <div class="col-lg-4 col-md-3 col-sm-3 hidden-sm hidden-xs padd-5">
#       <a class="cds" href="http://www.creadoresdesitios.com.ar" target="_blank">
#        <span class="hidden-md">
#         Desarrollo Web /
#        </span>
#        Creadores de Sitios
#       </a>
#      </div>
#      <div class="col-md-12 col-xs-12 hidden-md hidden-lg text-center">
#       <a href="http://www.lemotsur.com.ar" target="_blank">
#       </a>
#      </div>
#     </div>
#    </div>
#   </section>
#   <!-- The Bootstrap Image Gallery lightbox, should be a child element of the document body -->
#   <div class="blueimp-gallery blueimp-gallery-controls" id="blueimp-gallery">
#    <!-- The container for the modal slides -->
#    <div class="slides">
#    </div>
#    <!-- Controls for the borderless lightbox -->
#    <h3 class="title">
#    </h3>
#    <a class="prev">
#     ‹
#    </a>
#    <a class="next">
#     ›
#    </a>
#    <a class="close">
#     ×
#    </a>
#    <a class="play-pause">
#    </a>
#    <ol class="indicator">
#    </ol>
#    <!-- The modal dialog, which will be used to wrap the lightbox content -->
#    <div class="modal fade">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" type="button">
#         ×
#        </button>
#        <h4 class="modal-title">
#        </h4>
#       </div>
#       <div class="modal-body next">
#       </div>
#       <div class="modal-footer">
#        <button class="btn btn-default pull-left prev" type="button">
#         <i class="glyphicon glyphicon-chevron-left">
#         </i>
#         Previous
#        </button>
#        <button class="btn btn-primary next" type="button">
#         Next
#         <i class="glyphicon glyphicon-chevron-right">
#         </i>
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- JS GENERAL -->
#   <script src="js/jquery.min.js">
#   </script>
#   <script src="js/bootstrap.js">
#   </script>
#   <!-- MARQUESINA -->
#   <script src="js/jquery.smarticker.min.js" type="text/javascript">
#   </script>
#   <script>
#    $('.smarticker1').smarticker({
#     controllerType: 1,
#     title: 'ÚLTIMAS NOTICIAS',
#     animation: 'slide',
#     speed: 1000,
#     progressbar: false
#     });
#   </script>
#   <script src="js/common.js?v=1.9">
#   </script>
#   <!-- GALERIA -->
#   <script src="js/jquery.blueimp-gallery.min.js">
#   </script>
#   <script src="js/bootstrap-image-gallery.js">
#   </script>
#   <script language="JavaScript">
#    /*------------ JS BUSQUEDA --------------------*/
#         /*$(".buy-search").hide();*/
#         $(".boton-nota-despliega").click(function(){
#             $(".nota-despliega").stop();
#             if ($(".nota-despliega").hasClass("on")){
#                 $(".nota-despliega").slideUp();
#                 $(".nota-despliega").removeClass("on");
#             } else {
#                 $(".nota-despliega").slideDown();
#                 $(".nota-despliega").addClass("on");
#             }
#         });
#     /*------------ FIN JS BUSQUEDA --------------------*/
#
# (function($) {
#   $(document).ready(function(){
#     $(".cerrar-nota").on("click", function(){
#       $(this).toggleClass("check").toggleClass("uncheck");
#     });
#   });
# })(jQuery);
#   </script>
#   <!-- OWL CAROUSEL -->
#   <script src="js/owl-carousel/owl.carousel.min.js">
#   </script>
#   <script src="js/owl-carousel/owl_slider.js">
#   </script>
#   <script language="JavaScript">
#    /*------------ JS BUSQUEDA --------------------*/
# 	/*$(".buy-search").hide();*/
# 	$(".boton-menu-top").click(function(){
# 		$(".buy-search").stop();
# 		if ($(this).hasClass("on")){
# 			$(".buy-search").slideUp();
# 			$(this).removeClass("on");
# 		} else {
# 			$(".buy-search").slideDown();
# 			$(this).addClass("on");
# 		}
# 	});
# /*------------ FIN JS BUSQUEDA --------------------*/
#   </script>
#  </body>
# </html>
